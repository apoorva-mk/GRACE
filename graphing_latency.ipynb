# %%
no_cache_profile = [{'NODE RETRIEVAL': 2.352224111557007,
  'NODE TRAVERSAL': 0.3427581787109375,
  'DOCUMENT RETRIEVAL': 0.4730985164642334,
  'NUM TOTAL DOCUMENTS': 91},
 {'NODE RETRIEVAL': 2.973215103149414,
  'NODE TRAVERSAL': 0.9344851970672607,
  'DOCUMENT RETRIEVAL': 7.2879979610443115,
  'NUM TOTAL DOCUMENTS': 870},
 {'NODE RETRIEVAL': 2.456045150756836,
  'NODE TRAVERSAL': 1.5092813968658447,
  'DOCUMENT RETRIEVAL': 5.492200136184692,
  'NUM TOTAL DOCUMENTS': 463},
 {'NODE RETRIEVAL': 2.147651195526123,
  'NODE TRAVERSAL': 1.3061439990997314,
  'DOCUMENT RETRIEVAL': 2.8688249588012695,
  'NUM TOTAL DOCUMENTS': 357},
 {'NODE RETRIEVAL': 1.906040906906128,
  'NODE TRAVERSAL': 1.2125654220581055,
  'DOCUMENT RETRIEVAL': 0.296114444732666,
  'NUM TOTAL DOCUMENTS': 37},
 {'NODE RETRIEVAL': 2.941758155822754,
  'NODE TRAVERSAL': 1.0974712371826172,
  'DOCUMENT RETRIEVAL': 3.946476697921753,
  'NUM TOTAL DOCUMENTS': 86},
 {'NODE RETRIEVAL': 2.236164093017578,
  'NODE TRAVERSAL': 3.0189599990844727,
  'DOCUMENT RETRIEVAL': 43.021573305130005,
  'NUM TOTAL DOCUMENTS': 1441},
 {'NODE RETRIEVAL': 2.330177068710327,
  'NODE TRAVERSAL': 1.188962459564209,
  'DOCUMENT RETRIEVAL': 0.48055100440979004,
  'NUM TOTAL DOCUMENTS': 61},
 {'NODE RETRIEVAL': 2.741863965988159,
  'NODE TRAVERSAL': 1.2097556591033936,
  'DOCUMENT RETRIEVAL': 0.5542516708374023,
  'NUM TOTAL DOCUMENTS': 75},
 {'NODE RETRIEVAL': 1.833773136138916,
  'NODE TRAVERSAL': 0.5203561782836914,
  'DOCUMENT RETRIEVAL': 1.3902370929718018,
  'NUM TOTAL DOCUMENTS': 247},
 {'NODE RETRIEVAL': 2.7028849124908447,
  'NODE TRAVERSAL': 0.7943606376647949,
  'DOCUMENT RETRIEVAL': 0.26604223251342773,
  'NUM TOTAL DOCUMENTS': 13},
 {'NODE RETRIEVAL': 1.8760037422180176,
  'NODE TRAVERSAL': 0.6385393142700195,
  'DOCUMENT RETRIEVAL': 12.793713092803955,
  'NUM TOTAL DOCUMENTS': 660},
 {'NODE RETRIEVAL': 2.1343328952789307,
  'NODE TRAVERSAL': 0.45528173446655273,
  'DOCUMENT RETRIEVAL': 0.3834214210510254,
  'NUM TOTAL DOCUMENTS': 20},
 {'NODE RETRIEVAL': 2.540839910507202,
  'NODE TRAVERSAL': 0.8281309604644775,
  'DOCUMENT RETRIEVAL': 2.683307647705078,
  'NUM TOTAL DOCUMENTS': 351},
 {'NODE RETRIEVAL': 1.8683509826660156,
  'NODE TRAVERSAL': 1.0546135902404785,
  'DOCUMENT RETRIEVAL': 22.079669713974,
  'NUM TOTAL DOCUMENTS': 778},
 {'NODE RETRIEVAL': 2.5587940216064453,
  'NODE TRAVERSAL': 4.906296253204346,
  'DOCUMENT RETRIEVAL': 65.03077554702759,
  'NUM TOTAL DOCUMENTS': 1258},
 {'NODE RETRIEVAL': 2.046696901321411,
  'NODE TRAVERSAL': 0.5629312992095947,
  'DOCUMENT RETRIEVAL': 0.30199360847473145,
  'NUM TOTAL DOCUMENTS': 30},
 {'NODE RETRIEVAL': 1.8441531658172607,
  'NODE TRAVERSAL': 1.3018858432769775,
  'DOCUMENT RETRIEVAL': 8.5645432472229,
  'NUM TOTAL DOCUMENTS': 822},
 {'NODE RETRIEVAL': 1.9216079711914062,
  'NODE TRAVERSAL': 0.9777777194976807,
  'DOCUMENT RETRIEVAL': 9.040035247802734,
  'NUM TOTAL DOCUMENTS': 970},
 {'NODE RETRIEVAL': 2.1170969009399414,
  'NODE TRAVERSAL': 1.0210342407226562,
  'DOCUMENT RETRIEVAL': 0.36524057388305664,
  'NUM TOTAL DOCUMENTS': 48},
 {'NODE RETRIEVAL': 2.3704099655151367,
  'NODE TRAVERSAL': 0.8791024684906006,
  'DOCUMENT RETRIEVAL': 4.258706331253052,
  'NUM TOTAL DOCUMENTS': 79},
 {'NODE RETRIEVAL': 2.048121213912964,
  'NODE TRAVERSAL': 0.6373980045318604,
  'DOCUMENT RETRIEVAL': 0.23522281646728516,
  'NUM TOTAL DOCUMENTS': 19},
 {'NODE RETRIEVAL': 2.308681011199951,
  'NODE TRAVERSAL': 0.820457935333252,
  'DOCUMENT RETRIEVAL': 2.913419485092163,
  'NUM TOTAL DOCUMENTS': 280},
 {'NODE RETRIEVAL': 2.6482112407684326,
  'NODE TRAVERSAL': 0.5645065307617188,
  'DOCUMENT RETRIEVAL': 0.27611780166625977,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 2.9608700275421143,
  'NODE TRAVERSAL': 0.7471225261688232,
  'DOCUMENT RETRIEVAL': 0.7668271064758301,
  'NUM TOTAL DOCUMENTS': 123},
 {'NODE RETRIEVAL': 3.196932077407837,
  'NODE TRAVERSAL': 0.7328004837036133,
  'DOCUMENT RETRIEVAL': 3.4937829971313477,
  'NUM TOTAL DOCUMENTS': 450},
 {'NODE RETRIEVAL': 2.2831592559814453,
  'NODE TRAVERSAL': 1.8682305812835693,
  'DOCUMENT RETRIEVAL': 21.92865538597107,
  'NUM TOTAL DOCUMENTS': 1132},
 {'NODE RETRIEVAL': 1.8494648933410645,
  'NODE TRAVERSAL': 0.88948655128479,
  'DOCUMENT RETRIEVAL': 0.15982627868652344,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 2.8530523777008057,
  'NODE TRAVERSAL': 1.3760135173797607,
  'DOCUMENT RETRIEVAL': 0.29190802574157715,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 2.2430379390716553,
  'NODE TRAVERSAL': 0.7367300987243652,
  'DOCUMENT RETRIEVAL': 0.14601850509643555,
  'NUM TOTAL DOCUMENTS': 15},
 {'NODE RETRIEVAL': 2.024228096008301,
  'NODE TRAVERSAL': 0.7725973129272461,
  'DOCUMENT RETRIEVAL': 0.23974323272705078,
  'NUM TOTAL DOCUMENTS': 26},
 {'NODE RETRIEVAL': 2.566680908203125,
  'NODE TRAVERSAL': 0.807666540145874,
  'DOCUMENT RETRIEVAL': 19.1394145488739,
  'NUM TOTAL DOCUMENTS': 681},
 {'NODE RETRIEVAL': 25.00779700279236,
  'NODE TRAVERSAL': 0.9837591648101807,
  'DOCUMENT RETRIEVAL': 10.953564405441284,
  'NUM TOTAL DOCUMENTS': 571},
 {'NODE RETRIEVAL': 2.3460278511047363,
  'NODE TRAVERSAL': 0.5550122261047363,
  'DOCUMENT RETRIEVAL': 1.4669952392578125,
  'NUM TOTAL DOCUMENTS': 147},
 {'NODE RETRIEVAL': 2.614837884902954,
  'NODE TRAVERSAL': 0.7155048847198486,
  'DOCUMENT RETRIEVAL': 21.251293897628784,
  'NUM TOTAL DOCUMENTS': 803},
 {'NODE RETRIEVAL': 2.0424418449401855,
  'NODE TRAVERSAL': 0.5927155017852783,
  'DOCUMENT RETRIEVAL': 0.7225799560546875,
  'NUM TOTAL DOCUMENTS': 49},
 {'NODE RETRIEVAL': 1.9306023120880127,
  'NODE TRAVERSAL': 0.49051523208618164,
  'DOCUMENT RETRIEVAL': 0.3980393409729004,
  'NUM TOTAL DOCUMENTS': 37},
 {'NODE RETRIEVAL': 2.3067917823791504,
  'NODE TRAVERSAL': 0.6696288585662842,
  'DOCUMENT RETRIEVAL': 2.8750579357147217,
  'NUM TOTAL DOCUMENTS': 144},
 {'NODE RETRIEVAL': 2.0520970821380615,
  'NODE TRAVERSAL': 0.6844127178192139,
  'DOCUMENT RETRIEVAL': 3.7748849391937256,
  'NUM TOTAL DOCUMENTS': 184},
 {'NODE RETRIEVAL': 2.3702809810638428,
  'NODE TRAVERSAL': 0.5979578495025635,
  'DOCUMENT RETRIEVAL': 0.2418351173400879,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 2.283620834350586,
  'NODE TRAVERSAL': 0.5785620212554932,
  'DOCUMENT RETRIEVAL': 2.8282341957092285,
  'NUM TOTAL DOCUMENTS': 50},
 {'NODE RETRIEVAL': 2.2512362003326416,
  'NODE TRAVERSAL': 0.7391715049743652,
  'DOCUMENT RETRIEVAL': 3.2582476139068604,
  'NUM TOTAL DOCUMENTS': 63},
 {'NODE RETRIEVAL': 2.036329984664917,
  'NODE TRAVERSAL': 0.8383698463439941,
  'DOCUMENT RETRIEVAL': 0.6488344669342041,
  'NUM TOTAL DOCUMENTS': 40},
 {'NODE RETRIEVAL': 2.9532511234283447,
  'NODE TRAVERSAL': 0.7940185070037842,
  'DOCUMENT RETRIEVAL': 5.627403974533081,
  'NUM TOTAL DOCUMENTS': 230},
 {'NODE RETRIEVAL': 2.2462689876556396,
  'NODE TRAVERSAL': 0.7855422496795654,
  'DOCUMENT RETRIEVAL': 3.0276899337768555,
  'NUM TOTAL DOCUMENTS': 320},
 {'NODE RETRIEVAL': 2.1157679557800293,
  'NODE TRAVERSAL': 1.515347957611084,
  'DOCUMENT RETRIEVAL': 17.425066709518433,
  'NUM TOTAL DOCUMENTS': 1281},
 {'NODE RETRIEVAL': 1.8859171867370605,
  'NODE TRAVERSAL': 0.8799004554748535,
  'DOCUMENT RETRIEVAL': 0.35665035247802734,
  'NUM TOTAL DOCUMENTS': 49},
 {'NODE RETRIEVAL': 2.627774953842163,
  'NODE TRAVERSAL': 0.43262171745300293,
  'DOCUMENT RETRIEVAL': 0.38806915283203125,
  'NUM TOTAL DOCUMENTS': 87},
 {'NODE RETRIEVAL': 2.9580061435699463,
  'NODE TRAVERSAL': 1.2815401554107666,
  'DOCUMENT RETRIEVAL': 0.3329641819000244,
  'NUM TOTAL DOCUMENTS': 54},
 {'NODE RETRIEVAL': 1.8317039012908936,
  'NODE TRAVERSAL': 2.9166996479034424,
  'DOCUMENT RETRIEVAL': 31.41994071006775,
  'NUM TOTAL DOCUMENTS': 1251},
 {'NODE RETRIEVAL': 2.4432621002197266,
  'NODE TRAVERSAL': 1.2945120334625244,
  'DOCUMENT RETRIEVAL': 0.6075656414031982,
  'NUM TOTAL DOCUMENTS': 114},
 {'NODE RETRIEVAL': 26.801931858062744,
  'NODE TRAVERSAL': 0.8101935386657715,
  'DOCUMENT RETRIEVAL': 0.3094494342803955,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 2.031554937362671,
  'NODE TRAVERSAL': 1.0690371990203857,
  'DOCUMENT RETRIEVAL': 0.4969370365142822,
  'NUM TOTAL DOCUMENTS': 6},
 {'NODE RETRIEVAL': 2.102864980697632,
  'NODE TRAVERSAL': 0.7818107604980469,
  'DOCUMENT RETRIEVAL': 1.6729512214660645,
  'NUM TOTAL DOCUMENTS': 295},
 {'NODE RETRIEVAL': 1.9598431587219238,
  'NODE TRAVERSAL': 2.566075086593628,
  'DOCUMENT RETRIEVAL': 23.282607555389404,
  'NUM TOTAL DOCUMENTS': 1195},
 {'NODE RETRIEVAL': 1.996471881866455,
  'NODE TRAVERSAL': 0.4974493980407715,
  'DOCUMENT RETRIEVAL': 0.20664477348327637,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 2.2481882572174072,
  'NODE TRAVERSAL': 2.889249086380005,
  'DOCUMENT RETRIEVAL': 0.266986608505249,
  'NUM TOTAL DOCUMENTS': 36},
 {'NODE RETRIEVAL': 2.2636780738830566,
  'NODE TRAVERSAL': 1.0657758712768555,
  'DOCUMENT RETRIEVAL': 10.983623027801514,
  'NUM TOTAL DOCUMENTS': 1137},
 {'NODE RETRIEVAL': 2.021101951599121,
  'NODE TRAVERSAL': 0.8145847320556641,
  'DOCUMENT RETRIEVAL': 0.21815967559814453,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 2.050919771194458,
  'NODE TRAVERSAL': 3.6112828254699707,
  'DOCUMENT RETRIEVAL': 59.49337887763977,
  'NUM TOTAL DOCUMENTS': 1267},
 {'NODE RETRIEVAL': 2.06375789642334,
  'NODE TRAVERSAL': 0.9188032150268555,
  'DOCUMENT RETRIEVAL': 14.435908317565918,
  'NUM TOTAL DOCUMENTS': 1018},
 {'NODE RETRIEVAL': 3.7908129692077637,
  'NODE TRAVERSAL': 1.1728322505950928,
  'DOCUMENT RETRIEVAL': 1.8346061706542969,
  'NUM TOTAL DOCUMENTS': 172},
 {'NODE RETRIEVAL': 2.4691789150238037,
  'NODE TRAVERSAL': 0.5505597591400146,
  'DOCUMENT RETRIEVAL': 0.1345958709716797,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 2.3090901374816895,
  'NODE TRAVERSAL': 0.6904513835906982,
  'DOCUMENT RETRIEVAL': 0.14132452011108398,
  'NUM TOTAL DOCUMENTS': 24},
 {'NODE RETRIEVAL': 2.503293037414551,
  'NODE TRAVERSAL': 0.6072938442230225,
  'DOCUMENT RETRIEVAL': 4.5392372608184814,
  'NUM TOTAL DOCUMENTS': 408},
 {'NODE RETRIEVAL': 1.823012113571167,
  'NODE TRAVERSAL': 0.6292099952697754,
  'DOCUMENT RETRIEVAL': 6.156221866607666,
  'NUM TOTAL DOCUMENTS': 547},
 {'NODE RETRIEVAL': 2.304657220840454,
  'NODE TRAVERSAL': 0.6761643886566162,
  'DOCUMENT RETRIEVAL': 2.016751289367676,
  'NUM TOTAL DOCUMENTS': 157},
 {'NODE RETRIEVAL': 1.7890112400054932,
  'NODE TRAVERSAL': 0.5396420955657959,
  'DOCUMENT RETRIEVAL': 0.6373839378356934,
  'NUM TOTAL DOCUMENTS': 67},
 {'NODE RETRIEVAL': 2.1014480590820312,
  'NODE TRAVERSAL': 0.5257389545440674,
  'DOCUMENT RETRIEVAL': 0.3066856861114502,
  'NUM TOTAL DOCUMENTS': 42},
 {'NODE RETRIEVAL': 2.2590742111206055,
  'NODE TRAVERSAL': 0.7911484241485596,
  'DOCUMENT RETRIEVAL': 0.11833620071411133,
  'NUM TOTAL DOCUMENTS': 24},
 {'NODE RETRIEVAL': 2.0367496013641357,
  'NODE TRAVERSAL': 0.4981262683868408,
  'DOCUMENT RETRIEVAL': 0.8663914203643799,
  'NUM TOTAL DOCUMENTS': 54},
 {'NODE RETRIEVAL': 1.9143450260162354,
  'NODE TRAVERSAL': 1.5024223327636719,
  'DOCUMENT RETRIEVAL': 1.5255441665649414,
  'NUM TOTAL DOCUMENTS': 244},
 {'NODE RETRIEVAL': 2.2524240016937256,
  'NODE TRAVERSAL': 1.2997112274169922,
  'DOCUMENT RETRIEVAL': 0.3324308395385742,
  'NUM TOTAL DOCUMENTS': 29},
 {'NODE RETRIEVAL': 2.3928802013397217,
  'NODE TRAVERSAL': 0.6187098026275635,
  'DOCUMENT RETRIEVAL': 1.3267149925231934,
  'NUM TOTAL DOCUMENTS': 69},
 {'NODE RETRIEVAL': 1.9478600025177002,
  'NODE TRAVERSAL': 0.6032719612121582,
  'DOCUMENT RETRIEVAL': 1.4639384746551514,
  'NUM TOTAL DOCUMENTS': 190},
 {'NODE RETRIEVAL': 2.126483201980591,
  'NODE TRAVERSAL': 1.691300392150879,
  'DOCUMENT RETRIEVAL': 24.264241218566895,
  'NUM TOTAL DOCUMENTS': 1198},
 {'NODE RETRIEVAL': 1.966545820236206,
  'NODE TRAVERSAL': 0.4654552936553955,
  'DOCUMENT RETRIEVAL': 0.5138909816741943,
  'NUM TOTAL DOCUMENTS': 48},
 {'NODE RETRIEVAL': 2.4511351585388184,
  'NODE TRAVERSAL': 0.4455137252807617,
  'DOCUMENT RETRIEVAL': 0.4720277786254883,
  'NUM TOTAL DOCUMENTS': 82},
 {'NODE RETRIEVAL': 2.247274160385132,
  'NODE TRAVERSAL': 0.5743007659912109,
  'DOCUMENT RETRIEVAL': 0.37546324729919434,
  'NUM TOTAL DOCUMENTS': 12},
 {'NODE RETRIEVAL': 1.8540701866149902,
  'NODE TRAVERSAL': 0.6700582504272461,
  'DOCUMENT RETRIEVAL': 1.4040851593017578,
  'NUM TOTAL DOCUMENTS': 163},
 {'NODE RETRIEVAL': 1.8061110973358154,
  'NODE TRAVERSAL': 1.2904832363128662,
  'DOCUMENT RETRIEVAL': 8.539913892745972,
  'NUM TOTAL DOCUMENTS': 420},
 {'NODE RETRIEVAL': 1.975984811782837,
  'NODE TRAVERSAL': 0.7539980411529541,
  'DOCUMENT RETRIEVAL': 0.6478948593139648,
  'NUM TOTAL DOCUMENTS': 81},
 {'NODE RETRIEVAL': 2.7761659622192383,
  'NODE TRAVERSAL': 0.5914525985717773,
  'DOCUMENT RETRIEVAL': 1.2328827381134033,
  'NUM TOTAL DOCUMENTS': 213},
 {'NODE RETRIEVAL': 2.1768109798431396,
  'NODE TRAVERSAL': 0.5071461200714111,
  'DOCUMENT RETRIEVAL': 3.7341625690460205,
  'NUM TOTAL DOCUMENTS': 344},
 {'NODE RETRIEVAL': 3.6856460571289062,
  'NODE TRAVERSAL': 0.7959434986114502,
  'DOCUMENT RETRIEVAL': 2.258535623550415,
  'NUM TOTAL DOCUMENTS': 235},
 {'NODE RETRIEVAL': 2.707144021987915,
  'NODE TRAVERSAL': 0.8398890495300293,
  'DOCUMENT RETRIEVAL': 7.460034370422363,
  'NUM TOTAL DOCUMENTS': 215},
 {'NODE RETRIEVAL': 2.0382227897644043,
  'NODE TRAVERSAL': 0.6787376403808594,
  'DOCUMENT RETRIEVAL': 4.404095888137817,
  'NUM TOTAL DOCUMENTS': 544},
 {'NODE RETRIEVAL': 2.0271170139312744,
  'NODE TRAVERSAL': 0.8896825313568115,
  'DOCUMENT RETRIEVAL': 24.13145136833191,
  'NUM TOTAL DOCUMENTS': 975},
 {'NODE RETRIEVAL': 2.277090072631836,
  'NODE TRAVERSAL': 0.4059467315673828,
  'DOCUMENT RETRIEVAL': 0.6546487808227539,
  'NUM TOTAL DOCUMENTS': 46},
 {'NODE RETRIEVAL': 2.0065767765045166,
  'NODE TRAVERSAL': 3.1392502784729004,
  'DOCUMENT RETRIEVAL': 7.9104814529418945,
  'NUM TOTAL DOCUMENTS': 796},
 {'NODE RETRIEVAL': 1.9562382698059082,
  'NODE TRAVERSAL': 1.9325854778289795,
  'DOCUMENT RETRIEVAL': 27.586145639419556,
  'NUM TOTAL DOCUMENTS': 649},
 {'NODE RETRIEVAL': 2.064549207687378,
  'NODE TRAVERSAL': 0.8386611938476562,
  'DOCUMENT RETRIEVAL': 0.22728204727172852,
  'NUM TOTAL DOCUMENTS': 35},
 {'NODE RETRIEVAL': 2.918574810028076,
  'NODE TRAVERSAL': 0.40329933166503906,
  'DOCUMENT RETRIEVAL': 0.360431432723999,
  'NUM TOTAL DOCUMENTS': 19},
 {'NODE RETRIEVAL': 3.7346229553222656,
  'NODE TRAVERSAL': 0.6783199310302734,
  'DOCUMENT RETRIEVAL': 0.13001775741577148,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 1.9572253227233887,
  'NODE TRAVERSAL': 0.9967710971832275,
  'DOCUMENT RETRIEVAL': 12.289773225784302,
  'NUM TOTAL DOCUMENTS': 212},
 {'NODE RETRIEVAL': 2.6945738792419434,
  'NODE TRAVERSAL': 1.2738127708435059,
  'DOCUMENT RETRIEVAL': 21.93299150466919,
  'NUM TOTAL DOCUMENTS': 1166},
 {'NODE RETRIEVAL': 2.0979080200195312,
  'NODE TRAVERSAL': 0.4671196937561035,
  'DOCUMENT RETRIEVAL': 0.9777224063873291,
  'NUM TOTAL DOCUMENTS': 18},
 {'NODE RETRIEVAL': 1.7656240463256836,
  'NODE TRAVERSAL': 0.48044514656066895,
  'DOCUMENT RETRIEVAL': 1.0698142051696777,
  'NUM TOTAL DOCUMENTS': 113},
 {'NODE RETRIEVAL': 7.892782211303711,
  'NODE TRAVERSAL': 0.5446329116821289,
  'DOCUMENT RETRIEVAL': 1.1069536209106445,
  'NUM TOTAL DOCUMENTS': 67},
 {'NODE RETRIEVAL': 2.2416110038757324,
  'NODE TRAVERSAL': 0.5775964260101318,
  'DOCUMENT RETRIEVAL': 2.359966993331909,
  'NUM TOTAL DOCUMENTS': 268},
 {'NODE RETRIEVAL': 2.2003488540649414,
  'NODE TRAVERSAL': 0.8394863605499268,
  'DOCUMENT RETRIEVAL': 5.107193470001221,
  'NUM TOTAL DOCUMENTS': 386},
 {'NODE RETRIEVAL': 2.294687032699585,
  'NODE TRAVERSAL': 0.5227947235107422,
  'DOCUMENT RETRIEVAL': 1.1888229846954346,
  'NUM TOTAL DOCUMENTS': 162},
 {'NODE RETRIEVAL': 2.662569999694824,
  'NODE TRAVERSAL': 1.1922564506530762,
  'DOCUMENT RETRIEVAL': 0.8616816997528076,
  'NUM TOTAL DOCUMENTS': 45},
 {'NODE RETRIEVAL': 2.240062952041626,
  'NODE TRAVERSAL': 0.5257830619812012,
  'DOCUMENT RETRIEVAL': 0.538970947265625,
  'NUM TOTAL DOCUMENTS': 69},
 {'NODE RETRIEVAL': 2.0252370834350586,
  'NODE TRAVERSAL': 1.0736618041992188,
  'DOCUMENT RETRIEVAL': 21.58063507080078,
  'NUM TOTAL DOCUMENTS': 1082},
 {'NODE RETRIEVAL': 1.9169731140136719,
  'NODE TRAVERSAL': 0.5997593402862549,
  'DOCUMENT RETRIEVAL': 0.6319577693939209,
  'NUM TOTAL DOCUMENTS': 51},
 {'NODE RETRIEVAL': 3.2191920280456543,
  'NODE TRAVERSAL': 0.30698513984680176,
  'DOCUMENT RETRIEVAL': 0.26938366889953613,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 1.9462170600891113,
  'NODE TRAVERSAL': 0.4012119770050049,
  'DOCUMENT RETRIEVAL': 2.4411520957946777,
  'NUM TOTAL DOCUMENTS': 163},
 {'NODE RETRIEVAL': 2.454679012298584,
  'NODE TRAVERSAL': 0.4542050361633301,
  'DOCUMENT RETRIEVAL': 0.37395215034484863,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 1.8074431419372559,
  'NODE TRAVERSAL': 0.3642086982727051,
  'DOCUMENT RETRIEVAL': 1.026402235031128,
  'NUM TOTAL DOCUMENTS': 80},
 {'NODE RETRIEVAL': 1.9337220191955566,
  'NODE TRAVERSAL': 0.9609522819519043,
  'DOCUMENT RETRIEVAL': 4.0452880859375,
  'NUM TOTAL DOCUMENTS': 310},
 {'NODE RETRIEVAL': 1.936795949935913,
  'NODE TRAVERSAL': 0.6143712997436523,
  'DOCUMENT RETRIEVAL': 0.24896907806396484,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.0447208881378174,
  'NODE TRAVERSAL': 0.5443437099456787,
  'DOCUMENT RETRIEVAL': 0.4377260208129883,
  'NUM TOTAL DOCUMENTS': 25},
 {'NODE RETRIEVAL': 1.748859167098999,
  'NODE TRAVERSAL': 2.162584066390991,
  'DOCUMENT RETRIEVAL': 42.81110906600952,
  'NUM TOTAL DOCUMENTS': 1414},
 {'NODE RETRIEVAL': 2.243989944458008,
  'NODE TRAVERSAL': 0.5044600963592529,
  'DOCUMENT RETRIEVAL': 0.5108814239501953,
  'NUM TOTAL DOCUMENTS': 35},
 {'NODE RETRIEVAL': 2.045226573944092,
  'NODE TRAVERSAL': 0.5914790630340576,
  'DOCUMENT RETRIEVAL': 6.450151205062866,
  'NUM TOTAL DOCUMENTS': 816},
 {'NODE RETRIEVAL': 1.9186911582946777,
  'NODE TRAVERSAL': 0.916236162185669,
  'DOCUMENT RETRIEVAL': 7.666206121444702,
  'NUM TOTAL DOCUMENTS': 713},
 {'NODE RETRIEVAL': 2.3860280513763428,
  'NODE TRAVERSAL': 0.30765795707702637,
  'DOCUMENT RETRIEVAL': 0.3807528018951416,
  'NUM TOTAL DOCUMENTS': 12},
 {'NODE RETRIEVAL': 2.056368827819824,
  'NODE TRAVERSAL': 0.8968782424926758,
  'DOCUMENT RETRIEVAL': 14.51540756225586,
  'NUM TOTAL DOCUMENTS': 325},
 {'NODE RETRIEVAL': 2.3221850395202637,
  'NODE TRAVERSAL': 1.1755332946777344,
  'DOCUMENT RETRIEVAL': 20.54135274887085,
  'NUM TOTAL DOCUMENTS': 1545},
 {'NODE RETRIEVAL': 1.9341790676116943,
  'NODE TRAVERSAL': 0.8063597679138184,
  'DOCUMENT RETRIEVAL': 13.957705974578857,
  'NUM TOTAL DOCUMENTS': 947},
 {'NODE RETRIEVAL': 2.337512254714966,
  'NODE TRAVERSAL': 1.0541331768035889,
  'DOCUMENT RETRIEVAL': 3.8184492588043213,
  'NUM TOTAL DOCUMENTS': 363},
 {'NODE RETRIEVAL': 2.1554880142211914,
  'NODE TRAVERSAL': 0.5866389274597168,
  'DOCUMENT RETRIEVAL': 0.4988832473754883,
  'NUM TOTAL DOCUMENTS': 70},
 {'NODE RETRIEVAL': 1.9133450984954834,
  'NODE TRAVERSAL': 0.5620756149291992,
  'DOCUMENT RETRIEVAL': 5.943475723266602,
  'NUM TOTAL DOCUMENTS': 571},
 {'NODE RETRIEVAL': 2.002811908721924,
  'NODE TRAVERSAL': 0.548964262008667,
  'DOCUMENT RETRIEVAL': 0.6172189712524414,
  'NUM TOTAL DOCUMENTS': 114},
 {'NODE RETRIEVAL': 2.0487120151519775,
  'NODE TRAVERSAL': 0.4644448757171631,
  'DOCUMENT RETRIEVAL': 0.304962158203125,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 2.1134438514709473,
  'NODE TRAVERSAL': 0.3036670684814453,
  'DOCUMENT RETRIEVAL': 1.393005132675171,
  'NUM TOTAL DOCUMENTS': 185},
 {'NODE RETRIEVAL': 2.1931512355804443,
  'NODE TRAVERSAL': 0.6018829345703125,
  'DOCUMENT RETRIEVAL': 1.3764560222625732,
  'NUM TOTAL DOCUMENTS': 171},
 {'NODE RETRIEVAL': 2.1031861305236816,
  'NODE TRAVERSAL': 0.6882500648498535,
  'DOCUMENT RETRIEVAL': 1.4242684841156006,
  'NUM TOTAL DOCUMENTS': 139},
 {'NODE RETRIEVAL': 2.0052900314331055,
  'NODE TRAVERSAL': 9.44151759147644,
  'DOCUMENT RETRIEVAL': 91.7207248210907,
  'NUM TOTAL DOCUMENTS': 1382},
 {'NODE RETRIEVAL': 1.8600080013275146,
  'NODE TRAVERSAL': 0.3442878723144531,
  'DOCUMENT RETRIEVAL': 0.2864553928375244,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.075676918029785,
  'NODE TRAVERSAL': 0.4705522060394287,
  'DOCUMENT RETRIEVAL': 0.23368072509765625,
  'NUM TOTAL DOCUMENTS': 34},
 {'NODE RETRIEVAL': 2.690194845199585,
  'NODE TRAVERSAL': 1.1748902797698975,
  'DOCUMENT RETRIEVAL': 25.0595121383667,
  'NUM TOTAL DOCUMENTS': 1147},
 {'NODE RETRIEVAL': 2.25083327293396,
  'NODE TRAVERSAL': 0.95147705078125,
  'DOCUMENT RETRIEVAL': 4.666241407394409,
  'NUM TOTAL DOCUMENTS': 488},
 {'NODE RETRIEVAL': 1.8375277519226074,
  'NODE TRAVERSAL': 0.5654451847076416,
  'DOCUMENT RETRIEVAL': 1.5201561450958252,
  'NUM TOTAL DOCUMENTS': 114},
 {'NODE RETRIEVAL': 2.2495360374450684,
  'NODE TRAVERSAL': 0.7477912902832031,
  'DOCUMENT RETRIEVAL': 0.22292041778564453,
  'NUM TOTAL DOCUMENTS': 37},
 {'NODE RETRIEVAL': 2.7770278453826904,
  'NODE TRAVERSAL': 4.741805076599121,
  'DOCUMENT RETRIEVAL': 55.90139579772949,
  'NUM TOTAL DOCUMENTS': 1212},
 {'NODE RETRIEVAL': 2.663271903991699,
  'NODE TRAVERSAL': 0.35762476921081543,
  'DOCUMENT RETRIEVAL': 0.4160478115081787,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 2.245806932449341,
  'NODE TRAVERSAL': 0.6028158664703369,
  'DOCUMENT RETRIEVAL': 1.3978936672210693,
  'NUM TOTAL DOCUMENTS': 306},
 {'NODE RETRIEVAL': 2.043567180633545,
  'NODE TRAVERSAL': 0.4964144229888916,
  'DOCUMENT RETRIEVAL': 0.9562675952911377,
  'NUM TOTAL DOCUMENTS': 193},
 {'NODE RETRIEVAL': 2.451835870742798,
  'NODE TRAVERSAL': 0.35597848892211914,
  'DOCUMENT RETRIEVAL': 0.32251548767089844,
  'NUM TOTAL DOCUMENTS': 16},
 {'NODE RETRIEVAL': 1.9442417621612549,
  'NODE TRAVERSAL': 0.4289844036102295,
  'DOCUMENT RETRIEVAL': 0.8289222717285156,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 2.802762985229492,
  'NODE TRAVERSAL': 0.789625883102417,
  'DOCUMENT RETRIEVAL': 2.6785244941711426,
  'NUM TOTAL DOCUMENTS': 191},
 {'NODE RETRIEVAL': 2.8861610889434814,
  'NODE TRAVERSAL': 0.7720732688903809,
  'DOCUMENT RETRIEVAL': 1.1641058921813965,
  'NUM TOTAL DOCUMENTS': 19},
 {'NODE RETRIEVAL': 2.669304132461548,
  'NODE TRAVERSAL': 0.7395651340484619,
  'DOCUMENT RETRIEVAL': 1.2414181232452393,
  'NUM TOTAL DOCUMENTS': 136},
 {'NODE RETRIEVAL': 2.0835068225860596,
  'NODE TRAVERSAL': 0.4621455669403076,
  'DOCUMENT RETRIEVAL': 1.950618028640747,
  'NUM TOTAL DOCUMENTS': 116},
 {'NODE RETRIEVAL': 2.1906397342681885,
  'NODE TRAVERSAL': 0.43448400497436523,
  'DOCUMENT RETRIEVAL': 0.31974196434020996,
  'NUM TOTAL DOCUMENTS': 26},
 {'NODE RETRIEVAL': 1.8888099193572998,
  'NODE TRAVERSAL': 1.0515282154083252,
  'DOCUMENT RETRIEVAL': 24.389294624328613,
  'NUM TOTAL DOCUMENTS': 977},
 {'NODE RETRIEVAL': 2.0461220741271973,
  'NODE TRAVERSAL': 0.5835351943969727,
  'DOCUMENT RETRIEVAL': 1.1021595001220703,
  'NUM TOTAL DOCUMENTS': 55},
 {'NODE RETRIEVAL': 2.045902967453003,
  'NODE TRAVERSAL': 0.7549269199371338,
  'DOCUMENT RETRIEVAL': 9.525448560714722,
  'NUM TOTAL DOCUMENTS': 612},
 {'NODE RETRIEVAL': 1.932682991027832,
  'NODE TRAVERSAL': 0.41068339347839355,
  'DOCUMENT RETRIEVAL': 0.4444847106933594,
  'NUM TOTAL DOCUMENTS': 47},
 {'NODE RETRIEVAL': 2.0461268424987793,
  'NODE TRAVERSAL': 0.6302006244659424,
  'DOCUMENT RETRIEVAL': 1.3953807353973389,
  'NUM TOTAL DOCUMENTS': 197},
 {'NODE RETRIEVAL': 2.0494918823242188,
  'NODE TRAVERSAL': 0.9779727458953857,
  'DOCUMENT RETRIEVAL': 6.017341375350952,
  'NUM TOTAL DOCUMENTS': 555},
 {'NODE RETRIEVAL': 2.2625319957733154,
  'NODE TRAVERSAL': 0.7032656669616699,
  'DOCUMENT RETRIEVAL': 0.2620682716369629,
  'NUM TOTAL DOCUMENTS': 24},
 {'NODE RETRIEVAL': 2.6057798862457275,
  'NODE TRAVERSAL': 0.42989587783813477,
  'DOCUMENT RETRIEVAL': 0.8494188785552979,
  'NUM TOTAL DOCUMENTS': 55},
 {'NODE RETRIEVAL': 3.687643051147461,
  'NODE TRAVERSAL': 0.5014081001281738,
  'DOCUMENT RETRIEVAL': 1.741227626800537,
  'NUM TOTAL DOCUMENTS': 189},
 {'NODE RETRIEVAL': 2.571554183959961,
  'NODE TRAVERSAL': 0.4493699073791504,
  'DOCUMENT RETRIEVAL': 0.35608935356140137,
  'NUM TOTAL DOCUMENTS': 56},
 {'NODE RETRIEVAL': 2.0504069328308105,
  'NODE TRAVERSAL': 0.8469367027282715,
  'DOCUMENT RETRIEVAL': 0.12168741226196289,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 1.923548936843872,
  'NODE TRAVERSAL': 0.8656487464904785,
  'DOCUMENT RETRIEVAL': 8.276917695999146,
  'NUM TOTAL DOCUMENTS': 865},
 {'NODE RETRIEVAL': 2.6596410274505615,
  'NODE TRAVERSAL': 0.9410898685455322,
  'DOCUMENT RETRIEVAL': 0.3336467742919922,
  'NUM TOTAL DOCUMENTS': 25},
 {'NODE RETRIEVAL': 2.453317880630493,
  'NODE TRAVERSAL': 0.6471595764160156,
  'DOCUMENT RETRIEVAL': 9.343522310256958,
  'NUM TOTAL DOCUMENTS': 406},
 {'NODE RETRIEVAL': 2.6490349769592285,
  'NODE TRAVERSAL': 0.5871825218200684,
  'DOCUMENT RETRIEVAL': 7.031273603439331,
  'NUM TOTAL DOCUMENTS': 426},
 {'NODE RETRIEVAL': 2.247598648071289,
  'NODE TRAVERSAL': 0.9011521339416504,
  'DOCUMENT RETRIEVAL': 0.44634103775024414,
  'NUM TOTAL DOCUMENTS': 43},
 {'NODE RETRIEVAL': 2.2255759239196777,
  'NODE TRAVERSAL': 0.4430983066558838,
  'DOCUMENT RETRIEVAL': 0.2636394500732422,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 2.747684955596924,
  'NODE TRAVERSAL': 0.5367045402526855,
  'DOCUMENT RETRIEVAL': 2.594701051712036,
  'NUM TOTAL DOCUMENTS': 384},
 {'NODE RETRIEVAL': 2.393205165863037,
  'NODE TRAVERSAL': 1.2294950485229492,
  'DOCUMENT RETRIEVAL': 0.3277432918548584,
  'NUM TOTAL DOCUMENTS': 30},
 {'NODE RETRIEVAL': 2.1980080604553223,
  'NODE TRAVERSAL': 0.4208095073699951,
  'DOCUMENT RETRIEVAL': 0.6202371120452881,
  'NUM TOTAL DOCUMENTS': 7},
 {'NODE RETRIEVAL': 2.656092882156372,
  'NODE TRAVERSAL': 0.3809998035430908,
  'DOCUMENT RETRIEVAL': 0.6472663879394531,
  'NUM TOTAL DOCUMENTS': 101},
 {'NODE RETRIEVAL': 2.6624550819396973,
  'NODE TRAVERSAL': 0.5246734619140625,
  'DOCUMENT RETRIEVAL': 0.4165623188018799,
  'NUM TOTAL DOCUMENTS': 79},
 {'NODE RETRIEVAL': 2.098439931869507,
  'NODE TRAVERSAL': 0.3796415328979492,
  'DOCUMENT RETRIEVAL': 1.4695930480957031,
  'NUM TOTAL DOCUMENTS': 205},
 {'NODE RETRIEVAL': 2.120059013366699,
  'NODE TRAVERSAL': 0.6410269737243652,
  'DOCUMENT RETRIEVAL': 18.598878860473633,
  'NUM TOTAL DOCUMENTS': 864},
 {'NODE RETRIEVAL': 2.0431978702545166,
  'NODE TRAVERSAL': 0.5617852210998535,
  'DOCUMENT RETRIEVAL': 1.627638578414917,
  'NUM TOTAL DOCUMENTS': 136},
 {'NODE RETRIEVAL': 2.5376429557800293,
  'NODE TRAVERSAL': 1.9860334396362305,
  'DOCUMENT RETRIEVAL': 29.611938953399658,
  'NUM TOTAL DOCUMENTS': 1127},
 {'NODE RETRIEVAL': 2.624321222305298,
  'NODE TRAVERSAL': 0.47773313522338867,
  'DOCUMENT RETRIEVAL': 0.25009703636169434,
  'NUM TOTAL DOCUMENTS': 27},
 {'NODE RETRIEVAL': 2.8931009769439697,
  'NODE TRAVERSAL': 0.4132533073425293,
  'DOCUMENT RETRIEVAL': 0.36630678176879883,
  'NUM TOTAL DOCUMENTS': 37},
 {'NODE RETRIEVAL': 1.9441652297973633,
  'NODE TRAVERSAL': 2.1724929809570312,
  'DOCUMENT RETRIEVAL': 0.6917061805725098,
  'NUM TOTAL DOCUMENTS': 96},
 {'NODE RETRIEVAL': 2.4692060947418213,
  'NODE TRAVERSAL': 0.982349157333374,
  'DOCUMENT RETRIEVAL': 3.4605369567871094,
  'NUM TOTAL DOCUMENTS': 252},
 {'NODE RETRIEVAL': 3.0839428901672363,
  'NODE TRAVERSAL': 1.785585880279541,
  'DOCUMENT RETRIEVAL': 24.017185926437378,
  'NUM TOTAL DOCUMENTS': 1283},
 {'NODE RETRIEVAL': 2.244558095932007,
  'NODE TRAVERSAL': 0.5796647071838379,
  'DOCUMENT RETRIEVAL': 2.2945590019226074,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 2.4669370651245117,
  'NODE TRAVERSAL': 0.2961385250091553,
  'DOCUMENT RETRIEVAL': 0.6469528675079346,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.4522202014923096,
  'NODE TRAVERSAL': 0.41698503494262695,
  'DOCUMENT RETRIEVAL': 0.1255033016204834,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 2.0465071201324463,
  'NODE TRAVERSAL': 0.4224894046783447,
  'DOCUMENT RETRIEVAL': 0.5340275764465332,
  'NUM TOTAL DOCUMENTS': 75},
 {'NODE RETRIEVAL': 2.260516881942749,
  'NODE TRAVERSAL': 0.4526488780975342,
  'DOCUMENT RETRIEVAL': 0.9656863212585449,
  'NUM TOTAL DOCUMENTS': 29},
 {'NODE RETRIEVAL': 2.042781114578247,
  'NODE TRAVERSAL': 0.401139497756958,
  'DOCUMENT RETRIEVAL': 0.7838315963745117,
  'NUM TOTAL DOCUMENTS': 147},
 {'NODE RETRIEVAL': 2.4458179473876953,
  'NODE TRAVERSAL': 0.37773585319519043,
  'DOCUMENT RETRIEVAL': 0.07701635360717773,
  'NUM TOTAL DOCUMENTS': 18},
 {'NODE RETRIEVAL': 2.051456928253174,
  'NODE TRAVERSAL': 0.6632015705108643,
  'DOCUMENT RETRIEVAL': 13.395555973052979,
  'NUM TOTAL DOCUMENTS': 864},
 {'NODE RETRIEVAL': 2.5289218425750732,
  'NODE TRAVERSAL': 0.48902297019958496,
  'DOCUMENT RETRIEVAL': 0.7078680992126465,
  'NUM TOTAL DOCUMENTS': 67},
 {'NODE RETRIEVAL': 3.213589906692505,
  'NODE TRAVERSAL': 0.5785727500915527,
  'DOCUMENT RETRIEVAL': 0.9778358936309814,
  'NUM TOTAL DOCUMENTS': 122},
 {'NODE RETRIEVAL': 2.947416067123413,
  'NODE TRAVERSAL': 0.6417300701141357,
  'DOCUMENT RETRIEVAL': 0.6582024097442627,
  'NUM TOTAL DOCUMENTS': 43},
 {'NODE RETRIEVAL': 2.0599517822265625,
  'NODE TRAVERSAL': 2.0048182010650635,
  'DOCUMENT RETRIEVAL': 38.77703046798706,
  'NUM TOTAL DOCUMENTS': 1279},
 {'NODE RETRIEVAL': 2.888370990753174,
  'NODE TRAVERSAL': 0.4459986686706543,
  'DOCUMENT RETRIEVAL': 0.12535881996154785,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 1.7807679176330566,
  'NODE TRAVERSAL': 0.5035786628723145,
  'DOCUMENT RETRIEVAL': 3.6410210132598877,
  'NUM TOTAL DOCUMENTS': 434},
 {'NODE RETRIEVAL': 2.6623120307922363,
  'NODE TRAVERSAL': 0.491147518157959,
  'DOCUMENT RETRIEVAL': 1.5976612567901611,
  'NUM TOTAL DOCUMENTS': 192},
 {'NODE RETRIEVAL': 2.4449689388275146,
  'NODE TRAVERSAL': 0.49716758728027344,
  'DOCUMENT RETRIEVAL': 0.6942393779754639,
  'NUM TOTAL DOCUMENTS': 25},
 {'NODE RETRIEVAL': 2.245076894760132,
  'NODE TRAVERSAL': 1.0156538486480713,
  'DOCUMENT RETRIEVAL': 12.613166570663452,
  'NUM TOTAL DOCUMENTS': 678},
 {'NODE RETRIEVAL': 2.4404711723327637,
  'NODE TRAVERSAL': 0.46549391746520996,
  'DOCUMENT RETRIEVAL': 0.3844335079193115,
  'NUM TOTAL DOCUMENTS': 35},
 {'NODE RETRIEVAL': 2.349119186401367,
  'NODE TRAVERSAL': 0.9806230068206787,
  'DOCUMENT RETRIEVAL': 16.34941864013672,
  'NUM TOTAL DOCUMENTS': 561},
 {'NODE RETRIEVAL': 3.4578750133514404,
  'NODE TRAVERSAL': 1.2830438613891602,
  'DOCUMENT RETRIEVAL': 10.14388108253479,
  'NUM TOTAL DOCUMENTS': 451},
 {'NODE RETRIEVAL': 3.481618881225586,
  'NODE TRAVERSAL': 0.9082002639770508,
  'DOCUMENT RETRIEVAL': 0.45326948165893555,
  'NUM TOTAL DOCUMENTS': 50},
 {'NODE RETRIEVAL': 2.339534044265747,
  'NODE TRAVERSAL': 1.0740165710449219,
  'DOCUMENT RETRIEVAL': 0.6771972179412842,
  'NUM TOTAL DOCUMENTS': 99}]

# %%
cache_profile = [{'NODE RETRIEVAL': 2.551743984222412,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.005598306655883789,
  'CACHE RETRIEVAL': 0.007591724395751953,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 90},
 {'NODE RETRIEVAL': 2.0745961666107178,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.009440898895263672,
  'CACHE RETRIEVAL': 0.04606437683105469,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 851},
 {'NODE RETRIEVAL': 2.4628992080688477,
  'NODE TRAVERSAL': 0.41254615783691406,
  'DOCUMENT RETRIEVAL': 2.734778642654419,
  'READ FROM CACHE': 0.004494667053222656,
  'CACHE RETRIEVAL': 0.014463663101196289,
  'WRITE TO CACHE': 0.008331537246704102,
  'NUM TOTAL DOCUMENTS': 915},
 {'NODE RETRIEVAL': 2.2483298778533936,
  'NODE TRAVERSAL': 0.5857956409454346,
  'DOCUMENT RETRIEVAL': 2.3860254287719727,
  'READ FROM CACHE': 0.002363920211791992,
  'CACHE RETRIEVAL': 0.0007188320159912109,
  'WRITE TO CACHE': 0.042572736740112305,
  'NUM TOTAL DOCUMENTS': 364},
 {'NODE RETRIEVAL': 2.9482150077819824,
  'NODE TRAVERSAL': 0.7120800018310547,
  'DOCUMENT RETRIEVAL': 0.29261136054992676,
  'READ FROM CACHE': 0.0026845932006835938,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.004984617233276367,
  'NUM TOTAL DOCUMENTS': 38},
 {'NODE RETRIEVAL': 3.084320068359375,
  'NODE TRAVERSAL': 0.22945761680603027,
  'DOCUMENT RETRIEVAL': 1.8664472103118896,
  'READ FROM CACHE': 0.0032372474670410156,
  'CACHE RETRIEVAL': 0.008329153060913086,
  'WRITE TO CACHE': 0.0037970542907714844,
  'NUM TOTAL DOCUMENTS': 171},
 {'NODE RETRIEVAL': 2.6599910259246826,
  'NODE TRAVERSAL': 1.5203616619110107,
  'DOCUMENT RETRIEVAL': 25.14428734779358,
  'READ FROM CACHE': 0.01097249984741211,
  'CACHE RETRIEVAL': 0.05965995788574219,
  'WRITE TO CACHE': 0.03118419647216797,
  'NUM TOTAL DOCUMENTS': 2515},
 {'NODE RETRIEVAL': 2.41508412361145,
  'NODE TRAVERSAL': 0.5204184055328369,
  'DOCUMENT RETRIEVAL': 0.4676830768585205,
  'READ FROM CACHE': 0.0029168128967285156,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005486249923706055,
  'NUM TOTAL DOCUMENTS': 61},
 {'NODE RETRIEVAL': 2.660133123397827,
  'NODE TRAVERSAL': 0.5612082481384277,
  'DOCUMENT RETRIEVAL': 0.5078966617584229,
  'READ FROM CACHE': 0.0022525787353515625,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005255222320556641,
  'NUM TOTAL DOCUMENTS': 75},
 {'NODE RETRIEVAL': 1.8497929573059082,
  'NODE TRAVERSAL': 0.5959634780883789,
  'DOCUMENT RETRIEVAL': 1.2764780521392822,
  'READ FROM CACHE': 0.003221750259399414,
  'CACHE RETRIEVAL': 1.71661376953125e-05,
  'WRITE TO CACHE': 0.006915092468261719,
  'NUM TOTAL DOCUMENTS': 247},
 {'NODE RETRIEVAL': 2.043396234512329,
  'NODE TRAVERSAL': 0.18956732749938965,
  'DOCUMENT RETRIEVAL': 0.14792728424072266,
  'READ FROM CACHE': 0.0028696060180664062,
  'CACHE RETRIEVAL': 0.0012035369873046875,
  'WRITE TO CACHE': 0.003147125244140625,
  'NUM TOTAL DOCUMENTS': 25},
 {'NODE RETRIEVAL': 2.004279136657715,
  'NODE TRAVERSAL': 0.3583498001098633,
  'DOCUMENT RETRIEVAL': 5.399178743362427,
  'READ FROM CACHE': 0.006100893020629883,
  'CACHE RETRIEVAL': 0.02994084358215332,
  'WRITE TO CACHE': 0.00951838493347168,
  'NUM TOTAL DOCUMENTS': 1313},
 {'NODE RETRIEVAL': 2.7026753425598145,
  'NODE TRAVERSAL': 0.2104811668395996,
  'DOCUMENT RETRIEVAL': 0.20686697959899902,
  'READ FROM CACHE': 0.002353191375732422,
  'CACHE RETRIEVAL': 0.0010342597961425781,
  'WRITE TO CACHE': 0.002691030502319336,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 2.037792921066284,
  'NODE TRAVERSAL': 0.44910311698913574,
  'DOCUMENT RETRIEVAL': 2.1652677059173584,
  'READ FROM CACHE': 0.002703428268432617,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.008584260940551758,
  'NUM TOTAL DOCUMENTS': 351},
 {'NODE RETRIEVAL': 2.4399571418762207,
  'NODE TRAVERSAL': 0.3623652458190918,
  'DOCUMENT RETRIEVAL': 10.82684326171875,
  'READ FROM CACHE': 0.00536799430847168,
  'CACHE RETRIEVAL': 0.04545855522155762,
  'WRITE TO CACHE': 0.015848875045776367,
  'NUM TOTAL DOCUMENTS': 1202},
 {'NODE RETRIEVAL': 2.0439810752868652,
  'NODE TRAVERSAL': 1.6066527366638184,
  'DOCUMENT RETRIEVAL': 28.030516386032104,
  'READ FROM CACHE': 0.013854742050170898,
  'CACHE RETRIEVAL': 0.11608362197875977,
  'WRITE TO CACHE': 0.034012556076049805,
  'NUM TOTAL DOCUMENTS': 2496},
 {'NODE RETRIEVAL': 2.551994800567627,
  'NODE TRAVERSAL': 0.2052757740020752,
  'DOCUMENT RETRIEVAL': 0.19138145446777344,
  'READ FROM CACHE': 0.0021364688873291016,
  'CACHE RETRIEVAL': 0.0009558200836181641,
  'WRITE TO CACHE': 0.003377199172973633,
  'NUM TOTAL DOCUMENTS': 40},
 {'NODE RETRIEVAL': 2.2498929500579834,
  'NODE TRAVERSAL': 0.43751001358032227,
  'DOCUMENT RETRIEVAL': 7.8525776863098145,
  'READ FROM CACHE': 0.0023882389068603516,
  'CACHE RETRIEVAL': 0.00040984153747558594,
  'WRITE TO CACHE': 0.010497093200683594,
  'NUM TOTAL DOCUMENTS': 829},
 {'NODE RETRIEVAL': 2.2600297927856445,
  'NODE TRAVERSAL': 0.7052314281463623,
  'DOCUMENT RETRIEVAL': 7.310035705566406,
  'READ FROM CACHE': 0.00607609748840332,
  'CACHE RETRIEVAL': 0.02253890037536621,
  'WRITE TO CACHE': 0.009846687316894531,
  'NUM TOTAL DOCUMENTS': 1051},
 {'NODE RETRIEVAL': 2.2595629692077637,
  'NODE TRAVERSAL': 0.7090170383453369,
  'DOCUMENT RETRIEVAL': 0.29677844047546387,
  'READ FROM CACHE': 0.004332542419433594,
  'CACHE RETRIEVAL': 0.002758026123046875,
  'WRITE TO CACHE': 0.005043506622314453,
  'NUM TOTAL DOCUMENTS': 57},
 {'NODE RETRIEVAL': 2.9896152019500732,
  'NODE TRAVERSAL': 0.43404173851013184,
  'DOCUMENT RETRIEVAL': 1.2249348163604736,
  'READ FROM CACHE': 0.004304647445678711,
  'CACHE RETRIEVAL': 0.01645493507385254,
  'WRITE TO CACHE': 0.0032427310943603516,
  'NUM TOTAL DOCUMENTS': 134},
 {'NODE RETRIEVAL': 3.620590925216675,
  'NODE TRAVERSAL': 0.21735811233520508,
  'DOCUMENT RETRIEVAL': 0.16849946975708008,
  'READ FROM CACHE': 0.0030782222747802734,
  'CACHE RETRIEVAL': 0.0005640983581542969,
  'WRITE TO CACHE': 0.004477262496948242,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 3.125049114227295,
  'NODE TRAVERSAL': 0.6011343002319336,
  'DOCUMENT RETRIEVAL': 2.4256958961486816,
  'READ FROM CACHE': 0.002814769744873047,
  'CACHE RETRIEVAL': 0.0016260147094726562,
  'WRITE TO CACHE': 0.007597923278808594,
  'NUM TOTAL DOCUMENTS': 337},
 {'NODE RETRIEVAL': 2.99698805809021,
  'NODE TRAVERSAL': 0.571343183517456,
  'DOCUMENT RETRIEVAL': 0.14616918563842773,
  'READ FROM CACHE': 0.0033142566680908203,
  'CACHE RETRIEVAL': 0.0027434825897216797,
  'WRITE TO CACHE': 0.0031142234802246094,
  'NUM TOTAL DOCUMENTS': 27},
 {'NODE RETRIEVAL': 1.9690558910369873,
  'NODE TRAVERSAL': 0.266033411026001,
  'DOCUMENT RETRIEVAL': 0.6649889945983887,
  'READ FROM CACHE': 0.002611398696899414,
  'CACHE RETRIEVAL': 0.0007283687591552734,
  'WRITE TO CACHE': 0.004877567291259766,
  'NUM TOTAL DOCUMENTS': 134},
 {'NODE RETRIEVAL': 2.247689962387085,
  'NODE TRAVERSAL': 0.3778672218322754,
  'DOCUMENT RETRIEVAL': 3.0573606491088867,
  'READ FROM CACHE': 0.002432107925415039,
  'CACHE RETRIEVAL': 0.0006458759307861328,
  'WRITE TO CACHE': 0.007717132568359375,
  'NUM TOTAL DOCUMENTS': 450},
 {'NODE RETRIEVAL': 3.069214105606079,
  'NODE TRAVERSAL': 0.898878812789917,
  'DOCUMENT RETRIEVAL': 11.208276510238647,
  'READ FROM CACHE': 0.007848262786865234,
  'CACHE RETRIEVAL': 0.05626702308654785,
  'WRITE TO CACHE': 0.014970541000366211,
  'NUM TOTAL DOCUMENTS': 1950},
 {'NODE RETRIEVAL': 2.069047212600708,
  'NODE TRAVERSAL': 0.43326783180236816,
  'DOCUMENT RETRIEVAL': 0.13233280181884766,
  'READ FROM CACHE': 0.0037071704864501953,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005993843078613281,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 2.1836390495300293,
  'NODE TRAVERSAL': 0.18428349494934082,
  'DOCUMENT RETRIEVAL': 0.19295144081115723,
  'READ FROM CACHE': 0.002661466598510742,
  'CACHE RETRIEVAL': 0.0010006427764892578,
  'WRITE TO CACHE': 0.0034682750701904297,
  'NUM TOTAL DOCUMENTS': 25},
 {'NODE RETRIEVAL': 2.04565691947937,
  'NODE TRAVERSAL': 0.22222280502319336,
  'DOCUMENT RETRIEVAL': 0.11047053337097168,
  'READ FROM CACHE': 0.003954887390136719,
  'CACHE RETRIEVAL': 0.00046515464782714844,
  'WRITE TO CACHE': 0.004735231399536133,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.407947063446045,
  'NODE TRAVERSAL': 0.3000156879425049,
  'DOCUMENT RETRIEVAL': 0.23115849494934082,
  'READ FROM CACHE': 0.002964496612548828,
  'CACHE RETRIEVAL': 0.0003299713134765625,
  'WRITE TO CACHE': 0.004537820816040039,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 2.0470030307769775,
  'NODE TRAVERSAL': 0.2904376983642578,
  'DOCUMENT RETRIEVAL': 6.551144123077393,
  'READ FROM CACHE': 0.006671905517578125,
  'CACHE RETRIEVAL': 0.051811933517456055,
  'WRITE TO CACHE': 0.009524106979370117,
  'NUM TOTAL DOCUMENTS': 1329},
 {'NODE RETRIEVAL': 2.459341049194336,
  'NODE TRAVERSAL': 0.5080661773681641,
  'DOCUMENT RETRIEVAL': 5.398887872695923,
  'READ FROM CACHE': 0.004236459732055664,
  'CACHE RETRIEVAL': 0.01861095428466797,
  'WRITE TO CACHE': 0.010968685150146484,
  'NUM TOTAL DOCUMENTS': 877},
 {'NODE RETRIEVAL': 2.6642839908599854,
  'NODE TRAVERSAL': 0.23418092727661133,
  'DOCUMENT RETRIEVAL': 1.1214449405670166,
  'READ FROM CACHE': 0.004124164581298828,
  'CACHE RETRIEVAL': 0.004127979278564453,
  'WRITE TO CACHE': 0.005109071731567383,
  'NUM TOTAL DOCUMENTS': 194},
 {'NODE RETRIEVAL': 2.478976011276245,
  'NODE TRAVERSAL': 0.0830087661743164,
  'DOCUMENT RETRIEVAL': 2.081691026687622,
  'READ FROM CACHE': 0.012834787368774414,
  'CACHE RETRIEVAL': 0.11246728897094727,
  'WRITE TO CACHE': 0.004342794418334961,
  'NUM TOTAL DOCUMENTS': 1113},
 {'NODE RETRIEVAL': 2.357304811477661,
  'NODE TRAVERSAL': 0.28596067428588867,
  'DOCUMENT RETRIEVAL': 0.5443012714385986,
  'READ FROM CACHE': 0.003667116165161133,
  'CACHE RETRIEVAL': 0.0006320476531982422,
  'WRITE TO CACHE': 0.005591154098510742,
  'NUM TOTAL DOCUMENTS': 70},
 {'NODE RETRIEVAL': 2.453773021697998,
  'NODE TRAVERSAL': 0.43923115730285645,
  'DOCUMENT RETRIEVAL': 0.25623393058776855,
  'READ FROM CACHE': 0.0020978450775146484,
  'CACHE RETRIEVAL': 0.0009357929229736328,
  'WRITE TO CACHE': 0.0033943653106689453,
  'NUM TOTAL DOCUMENTS': 51},
 {'NODE RETRIEVAL': 6.714168071746826,
  'NODE TRAVERSAL': 0.16699004173278809,
  'DOCUMENT RETRIEVAL': 1.1620421409606934,
  'READ FROM CACHE': 0.0032787322998046875,
  'CACHE RETRIEVAL': 0.008566141128540039,
  'WRITE TO CACHE': 0.0037071704864501953,
  'NUM TOTAL DOCUMENTS': 280},
 {'NODE RETRIEVAL': 11.509013175964355,
  'NODE TRAVERSAL': 0.2168722152709961,
  'DOCUMENT RETRIEVAL': 1.3942077159881592,
  'READ FROM CACHE': 0.0033621788024902344,
  'CACHE RETRIEVAL': 0.011509895324707031,
  'WRITE TO CACHE': 0.0045566558837890625,
  'NUM TOTAL DOCUMENTS': 354},
 {'NODE RETRIEVAL': 2.253736972808838,
  'NODE TRAVERSAL': 0.2871222496032715,
  'DOCUMENT RETRIEVAL': 0.25415873527526855,
  'READ FROM CACHE': 0.0037004947662353516,
  'CACHE RETRIEVAL': 2.002716064453125e-05,
  'WRITE TO CACHE': 0.005137443542480469,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 8.561812162399292,
  'NODE TRAVERSAL': 0.3459768295288086,
  'DOCUMENT RETRIEVAL': 1.1988298892974854,
  'READ FROM CACHE': 0.003093242645263672,
  'CACHE RETRIEVAL': 0.00785064697265625,
  'WRITE TO CACHE': 0.0029191970825195312,
  'NUM TOTAL DOCUMENTS': 99},
 {'NODE RETRIEVAL': 6.531631946563721,
  'NODE TRAVERSAL': 0.12135696411132812,
  'DOCUMENT RETRIEVAL': 0.7561566829681396,
  'READ FROM CACHE': 0.0033655166625976562,
  'CACHE RETRIEVAL': 0.012742757797241211,
  'WRITE TO CACHE': 0.0018932819366455078,
  'NUM TOTAL DOCUMENTS': 104},
 {'NODE RETRIEVAL': 7.7893078327178955,
  'NODE TRAVERSAL': 0.3900611400604248,
  'DOCUMENT RETRIEVAL': 0.5331947803497314,
  'READ FROM CACHE': 0.002600431442260742,
  'CACHE RETRIEVAL': 0.0003590583801269531,
  'WRITE TO CACHE': 0.0038716793060302734,
  'NUM TOTAL DOCUMENTS': 40},
 {'NODE RETRIEVAL': 6.136721849441528,
  'NODE TRAVERSAL': 0.31751489639282227,
  'DOCUMENT RETRIEVAL': 2.9460713863372803,
  'READ FROM CACHE': 0.0034224987030029297,
  'CACHE RETRIEVAL': 0.014163017272949219,
  'WRITE TO CACHE': 0.007614850997924805,
  'NUM TOTAL DOCUMENTS': 443},
 {'NODE RETRIEVAL': 3.0639641284942627,
  'NODE TRAVERSAL': 0.4453699588775635,
  'DOCUMENT RETRIEVAL': 2.360046148300171,
  'READ FROM CACHE': 0.004728078842163086,
  'CACHE RETRIEVAL': 0.01771998405456543,
  'WRITE TO CACHE': 0.0065500736236572266,
  'NUM TOTAL DOCUMENTS': 481},
 {'NODE RETRIEVAL': 2.2510180473327637,
  'NODE TRAVERSAL': 0.8138558864593506,
  'DOCUMENT RETRIEVAL': 15.084514617919922,
  'READ FROM CACHE': 0.0031518936157226562,
  'CACHE RETRIEVAL': 0.0014438629150390625,
  'WRITE TO CACHE': 0.01975226402282715,
  'NUM TOTAL DOCUMENTS': 1317},
 {'NODE RETRIEVAL': 1.9467029571533203,
  'NODE TRAVERSAL': 0.2847774028778076,
  'DOCUMENT RETRIEVAL': 0.3395094871520996,
  'READ FROM CACHE': 0.0026814937591552734,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005463361740112305,
  'NUM TOTAL DOCUMENTS': 49},
 {'NODE RETRIEVAL': 2.1706130504608154,
  'NODE TRAVERSAL': 0.2909114360809326,
  'DOCUMENT RETRIEVAL': 0.3894820213317871,
  'READ FROM CACHE': 0.0024309158325195312,
  'CACHE RETRIEVAL': 1.1205673217773438e-05,
  'WRITE TO CACHE': 0.003863811492919922,
  'NUM TOTAL DOCUMENTS': 85},
 {'NODE RETRIEVAL': 1.999075174331665,
  'NODE TRAVERSAL': 0.4586658477783203,
  'DOCUMENT RETRIEVAL': 0.2524888515472412,
  'READ FROM CACHE': 0.002557992935180664,
  'CACHE RETRIEVAL': 0.00038623809814453125,
  'WRITE TO CACHE': 0.004632472991943359,
  'NUM TOTAL DOCUMENTS': 63},
 {'NODE RETRIEVAL': 1.846275806427002,
  'NODE TRAVERSAL': 0.1312541961669922,
  'DOCUMENT RETRIEVAL': 0.12233281135559082,
  'READ FROM CACHE': 0.012626171112060547,
  'CACHE RETRIEVAL': 0.0901639461517334,
  'WRITE TO CACHE': 0.0017898082733154297,
  'NUM TOTAL DOCUMENTS': 1243},
 {'NODE RETRIEVAL': 6.963328838348389,
  'NODE TRAVERSAL': 0.6368520259857178,
  'DOCUMENT RETRIEVAL': 0.5588328838348389,
  'READ FROM CACHE': 0.003845691680908203,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.007383584976196289,
  'NUM TOTAL DOCUMENTS': 118},
 {'NODE RETRIEVAL': 11.001229047775269,
  'NODE TRAVERSAL': 0.9678263664245605,
  'DOCUMENT RETRIEVAL': 0.23978734016418457,
  'READ FROM CACHE': 0.0028579235076904297,
  'CACHE RETRIEVAL': 0.0005478858947753906,
  'WRITE TO CACHE': 0.004437446594238281,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 6.541382789611816,
  'NODE TRAVERSAL': 0.1728370189666748,
  'DOCUMENT RETRIEVAL': 0.10959625244140625,
  'READ FROM CACHE': 0.001703500747680664,
  'CACHE RETRIEVAL': 0.001344442367553711,
  'WRITE TO CACHE': 0.0013620853424072266,
  'NUM TOTAL DOCUMENTS': 12},
 {'NODE RETRIEVAL': 3.483036994934082,
  'NODE TRAVERSAL': 0.36714839935302734,
  'DOCUMENT RETRIEVAL': 1.5624899864196777,
  'READ FROM CACHE': 0.0027472972869873047,
  'CACHE RETRIEVAL': 9.059906005859375e-06,
  'WRITE TO CACHE': 0.006893157958984375,
  'NUM TOTAL DOCUMENTS': 294},
 {'NODE RETRIEVAL': 3.68630313873291,
  'NODE TRAVERSAL': 0.6101405620574951,
  'DOCUMENT RETRIEVAL': 5.792013168334961,
  'READ FROM CACHE': 0.014251708984375,
  'CACHE RETRIEVAL': 0.08556270599365234,
  'WRITE TO CACHE': 0.011049032211303711,
  'NUM TOTAL DOCUMENTS': 1754},
 {'NODE RETRIEVAL': 2.254944086074829,
  'NODE TRAVERSAL': 0.3364996910095215,
  'DOCUMENT RETRIEVAL': 0.17378664016723633,
  'READ FROM CACHE': 0.0040018558502197266,
  'CACHE RETRIEVAL': 0.0011317729949951172,
  'WRITE TO CACHE': 0.004602193832397461,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 6.150096893310547,
  'NODE TRAVERSAL': 0.34611034393310547,
  'DOCUMENT RETRIEVAL': 0.22476506233215332,
  'READ FROM CACHE': 0.003687620162963867,
  'CACHE RETRIEVAL': 0.0017938613891601562,
  'WRITE TO CACHE': 0.004698753356933594,
  'NUM TOTAL DOCUMENTS': 49},
 {'NODE RETRIEVAL': 2.2509329319000244,
  'NODE TRAVERSAL': 0.3212099075317383,
  'DOCUMENT RETRIEVAL': 2.3060314655303955,
  'READ FROM CACHE': 0.005120754241943359,
  'CACHE RETRIEVAL': 0.03296780586242676,
  'WRITE TO CACHE': 0.006265163421630859,
  'NUM TOTAL DOCUMENTS': 1495},
 {'NODE RETRIEVAL': 4.576078176498413,
  'NODE TRAVERSAL': 0.3918914794921875,
  'DOCUMENT RETRIEVAL': 0.15006446838378906,
  'READ FROM CACHE': 0.0035212039947509766,
  'CACHE RETRIEVAL': 0.0005500316619873047,
  'WRITE TO CACHE': 0.004970073699951172,
  'NUM TOTAL DOCUMENTS': 42},
 {'NODE RETRIEVAL': 3.5745537281036377,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.01744818687438965,
  'CACHE RETRIEVAL': 0.2023484706878662,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 1247},
 {'NODE RETRIEVAL': 2.0435709953308105,
  'NODE TRAVERSAL': 0.6987960338592529,
  'DOCUMENT RETRIEVAL': 12.504415035247803,
  'READ FROM CACHE': 0.0027616024017333984,
  'CACHE RETRIEVAL': 0.009598970413208008,
  'WRITE TO CACHE': 0.016858816146850586,
  'NUM TOTAL DOCUMENTS': 1374},
 {'NODE RETRIEVAL': 10.802503824234009,
  'NODE TRAVERSAL': 0.07660579681396484,
  'DOCUMENT RETRIEVAL': 0.0631551742553711,
  'READ FROM CACHE': 0.005139827728271484,
  'CACHE RETRIEVAL': 0.023680925369262695,
  'WRITE TO CACHE': 0.000865936279296875,
  'NUM TOTAL DOCUMENTS': 176},
 {'NODE RETRIEVAL': 8.004740238189697,
  'NODE TRAVERSAL': 0.38284850120544434,
  'DOCUMENT RETRIEVAL': 0.1392512321472168,
  'READ FROM CACHE': 0.003686189651489258,
  'CACHE RETRIEVAL': 4.100799560546875e-05,
  'WRITE TO CACHE': 0.0047037601470947266,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 11.682252168655396,
  'NODE TRAVERSAL': 0.43262457847595215,
  'DOCUMENT RETRIEVAL': 0.10227203369140625,
  'READ FROM CACHE': 0.0042841434478759766,
  'CACHE RETRIEVAL': 0.001009225845336914,
  'WRITE TO CACHE': 0.005360841751098633,
  'NUM TOTAL DOCUMENTS': 29},
 {'NODE RETRIEVAL': 17.20242428779602,
  'NODE TRAVERSAL': 0.7195994853973389,
  'DOCUMENT RETRIEVAL': 2.559802770614624,
  'READ FROM CACHE': 0.007177591323852539,
  'CACHE RETRIEVAL': 0.0366663932800293,
  'WRITE TO CACHE': 0.007846355438232422,
  'NUM TOTAL DOCUMENTS': 513},
 {'NODE RETRIEVAL': 9.41506576538086,
  'NODE TRAVERSAL': 0.4075603485107422,
  'DOCUMENT RETRIEVAL': 2.7672035694122314,
  'READ FROM CACHE': 0.00500178337097168,
  'CACHE RETRIEVAL': 0.017215728759765625,
  'WRITE TO CACHE': 0.0068302154541015625,
  'NUM TOTAL DOCUMENTS': 695},
 {'NODE RETRIEVAL': 2.4540140628814697,
  'NODE TRAVERSAL': 0.6367306709289551,
  'DOCUMENT RETRIEVAL': 0.8504199981689453,
  'READ FROM CACHE': 0.0033066272735595703,
  'CACHE RETRIEVAL': 0.007127285003662109,
  'WRITE TO CACHE': 0.0038640499114990234,
  'NUM TOTAL DOCUMENTS': 312},
 {'NODE RETRIEVAL': 6.743241786956787,
  'NODE TRAVERSAL': 0.41901087760925293,
  'DOCUMENT RETRIEVAL': 0.34839749336242676,
  'READ FROM CACHE': 0.0040361881256103516,
  'CACHE RETRIEVAL': 0.005898952484130859,
  'WRITE TO CACHE': 0.004770755767822266,
  'NUM TOTAL DOCUMENTS': 110},
 {'NODE RETRIEVAL': 2.0616800785064697,
  'NODE TRAVERSAL': 0.6290292739868164,
  'DOCUMENT RETRIEVAL': 0.30364394187927246,
  'READ FROM CACHE': 0.0037572383880615234,
  'CACHE RETRIEVAL': 0.0008301734924316406,
  'WRITE TO CACHE': 0.004782438278198242,
  'NUM TOTAL DOCUMENTS': 42},
 {'NODE RETRIEVAL': 2.0495128631591797,
  'NODE TRAVERSAL': 0.4018428325653076,
  'DOCUMENT RETRIEVAL': 0.10147380828857422,
  'READ FROM CACHE': 0.0036301612854003906,
  'CACHE RETRIEVAL': 1.3828277587890625e-05,
  'WRITE TO CACHE': 0.005199432373046875,
  'NUM TOTAL DOCUMENTS': 24},
 {'NODE RETRIEVAL': 3.8844871520996094,
  'NODE TRAVERSAL': 0.37390780448913574,
  'DOCUMENT RETRIEVAL': 0.5807549953460693,
  'READ FROM CACHE': 0.0026617050170898438,
  'CACHE RETRIEVAL': 0.0014939308166503906,
  'WRITE TO CACHE': 0.004307270050048828,
  'NUM TOTAL DOCUMENTS': 81},
 {'NODE RETRIEVAL': 8.385958909988403,
  'NODE TRAVERSAL': 0.7713677883148193,
  'DOCUMENT RETRIEVAL': 1.6233713626861572,
  'READ FROM CACHE': 0.0028128623962402344,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.007536649703979492,
  'NUM TOTAL DOCUMENTS': 247},
 {'NODE RETRIEVAL': 5.531414985656738,
  'NODE TRAVERSAL': 0.2648766040802002,
  'DOCUMENT RETRIEVAL': 0.10989975929260254,
  'READ FROM CACHE': 0.0022726058959960938,
  'CACHE RETRIEVAL': 0.0016028881072998047,
  'WRITE TO CACHE': 0.0026009082794189453,
  'NUM TOTAL DOCUMENTS': 29},
 {'NODE RETRIEVAL': 2.789263963699341,
  'NODE TRAVERSAL': 0.2299344539642334,
  'DOCUMENT RETRIEVAL': 0.7761156558990479,
  'READ FROM CACHE': 0.002137422561645508,
  'CACHE RETRIEVAL': 0.0030972957611083984,
  'WRITE TO CACHE': 0.0031359195709228516,
  'NUM TOTAL DOCUMENTS': 122},
 {'NODE RETRIEVAL': 3.2235069274902344,
  'NODE TRAVERSAL': 0.5300943851470947,
  'DOCUMENT RETRIEVAL': 1.2883999347686768,
  'READ FROM CACHE': 0.002392292022705078,
  'CACHE RETRIEVAL': 0.0005860328674316406,
  'WRITE TO CACHE': 0.005139350891113281,
  'NUM TOTAL DOCUMENTS': 195},
 {'NODE RETRIEVAL': 2.0888540744781494,
  'NODE TRAVERSAL': 0.5418026447296143,
  'DOCUMENT RETRIEVAL': 0.25233030319213867,
  'READ FROM CACHE': 0.018210411071777344,
  'CACHE RETRIEVAL': 0.33356475830078125,
  'WRITE TO CACHE': 0.002651214599609375,
  'NUM TOTAL DOCUMENTS': 1191},
 {'NODE RETRIEVAL': 2.248985767364502,
  'NODE TRAVERSAL': 0.531714916229248,
  'DOCUMENT RETRIEVAL': 0.33002495765686035,
  'READ FROM CACHE': 0.003387451171875,
  'CACHE RETRIEVAL': 0.004126310348510742,
  'WRITE TO CACHE': 0.004855155944824219,
  'NUM TOTAL DOCUMENTS': 69},
 {'NODE RETRIEVAL': 3.510580062866211,
  'NODE TRAVERSAL': 0.6953034400939941,
  'DOCUMENT RETRIEVAL': 0.4223513603210449,
  'READ FROM CACHE': 0.002756834030151367,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.0057125091552734375,
  'NUM TOTAL DOCUMENTS': 82},
 {'NODE RETRIEVAL': 2.4556849002838135,
  'NODE TRAVERSAL': 0.36696648597717285,
  'DOCUMENT RETRIEVAL': 0.21722888946533203,
  'READ FROM CACHE': 0.0028693675994873047,
  'CACHE RETRIEVAL': 0.0031020641326904297,
  'WRITE TO CACHE': 0.0023963451385498047,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 1.8417162895202637,
  'NODE TRAVERSAL': 0.48702144622802734,
  'DOCUMENT RETRIEVAL': 1.1973485946655273,
  'READ FROM CACHE': 0.002521514892578125,
  'CACHE RETRIEVAL': 0.0007588863372802734,
  'WRITE TO CACHE': 0.005349874496459961,
  'NUM TOTAL DOCUMENTS': 164},
 {'NODE RETRIEVAL': 2.03056263923645,
  'NODE TRAVERSAL': 1.0595307350158691,
  'DOCUMENT RETRIEVAL': 5.4446070194244385,
  'READ FROM CACHE': 0.003489971160888672,
  'CACHE RETRIEVAL': 0.015551567077636719,
  'WRITE TO CACHE': 0.011755228042602539,
  'NUM TOTAL DOCUMENTS': 649},
 {'NODE RETRIEVAL': 18.126856088638306,
  'NODE TRAVERSAL': 0.809030294418335,
  'DOCUMENT RETRIEVAL': 0.600182294845581,
  'READ FROM CACHE': 0.003325939178466797,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.0060422420501708984,
  'NUM TOTAL DOCUMENTS': 81},
 {'NODE RETRIEVAL': 2.9145190715789795,
  'NODE TRAVERSAL': 0.20868492126464844,
  'DOCUMENT RETRIEVAL': 0.42766833305358887,
  'READ FROM CACHE': 0.002663135528564453,
  'CACHE RETRIEVAL': 0.00587773323059082,
  'WRITE TO CACHE': 0.003332853317260742,
  'NUM TOTAL DOCUMENTS': 270},
 {'NODE RETRIEVAL': 13.109493970870972,
  'NODE TRAVERSAL': 0.3625810146331787,
  'DOCUMENT RETRIEVAL': 0.979259729385376,
  'READ FROM CACHE': 0.00334930419921875,
  'CACHE RETRIEVAL': 0.010233163833618164,
  'WRITE TO CACHE': 0.003484964370727539,
  'NUM TOTAL DOCUMENTS': 402},
 {'NODE RETRIEVAL': 2.1383299827575684,
  'NODE TRAVERSAL': 0.3382229804992676,
  'DOCUMENT RETRIEVAL': 1.5671494007110596,
  'READ FROM CACHE': 0.003258228302001953,
  'CACHE RETRIEVAL': 0.007678031921386719,
  'WRITE TO CACHE': 0.006070613861083984,
  'NUM TOTAL DOCUMENTS': 314},
 {'NODE RETRIEVAL': 2.2465908527374268,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.006345033645629883,
  'CACHE RETRIEVAL': 0.05313873291015625,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 214},
 {'NODE RETRIEVAL': 4.8246541023254395,
  'NODE TRAVERSAL': 0.9675192832946777,
  'DOCUMENT RETRIEVAL': 3.809424877166748,
  'READ FROM CACHE': 0.002855539321899414,
  'CACHE RETRIEVAL': 0.0026209354400634766,
  'WRITE TO CACHE': 0.008889198303222656,
  'NUM TOTAL DOCUMENTS': 590},
 {'NODE RETRIEVAL': 2.0648200511932373,
  'NODE TRAVERSAL': 0.4093761444091797,
  'DOCUMENT RETRIEVAL': 12.267542362213135,
  'READ FROM CACHE': 0.006907939910888672,
  'CACHE RETRIEVAL': 0.048950910568237305,
  'WRITE TO CACHE': 0.01514124870300293,
  'NUM TOTAL DOCUMENTS': 1432},
 {'NODE RETRIEVAL': 2.366447687149048,
  'NODE TRAVERSAL': 0.23468875885009766,
  'DOCUMENT RETRIEVAL': 0.3904104232788086,
  'READ FROM CACHE': 0.002365589141845703,
  'CACHE RETRIEVAL': 0.0018482208251953125,
  'WRITE TO CACHE': 0.003909111022949219,
  'NUM TOTAL DOCUMENTS': 76},
 {'NODE RETRIEVAL': 3.4794559478759766,
  'NODE TRAVERSAL': 0.44849324226379395,
  'DOCUMENT RETRIEVAL': 7.5192551612854,
  'READ FROM CACHE': 0.0025115013122558594,
  'CACHE RETRIEVAL': 0.0009748935699462891,
  'WRITE TO CACHE': 0.01053619384765625,
  'NUM TOTAL DOCUMENTS': 802},
 {'NODE RETRIEVAL': 2.438380002975464,
  'NODE TRAVERSAL': 0.9080088138580322,
  'DOCUMENT RETRIEVAL': 11.237612009048462,
  'READ FROM CACHE': 0.007204771041870117,
  'CACHE RETRIEVAL': 0.05663895606994629,
  'WRITE TO CACHE': 0.014032363891601562,
  'NUM TOTAL DOCUMENTS': 1292},
 {'NODE RETRIEVAL': 2.462494373321533,
  'NODE TRAVERSAL': 0.9052708148956299,
  'DOCUMENT RETRIEVAL': 0.11687421798706055,
  'READ FROM CACHE': 0.003981828689575195,
  'CACHE RETRIEVAL': 0.006463289260864258,
  'WRITE TO CACHE': 0.004116058349609375,
  'NUM TOTAL DOCUMENTS': 45},
 {'NODE RETRIEVAL': 9.870458841323853,
  'NODE TRAVERSAL': 0.9366965293884277,
  'DOCUMENT RETRIEVAL': 0.14765667915344238,
  'READ FROM CACHE': 0.0033659934997558594,
  'CACHE RETRIEVAL': 0.0021500587463378906,
  'WRITE TO CACHE': 0.003698587417602539,
  'NUM TOTAL DOCUMENTS': 29},
 {'NODE RETRIEVAL': 2.8608460426330566,
  'NODE TRAVERSAL': 0.44594383239746094,
  'DOCUMENT RETRIEVAL': 0.14253616333007812,
  'READ FROM CACHE': 0.004240751266479492,
  'CACHE RETRIEVAL': 0.0013551712036132812,
  'WRITE TO CACHE': 0.0055048465728759766,
  'NUM TOTAL DOCUMENTS': 34},
 {'NODE RETRIEVAL': 2.4519360065460205,
  'NODE TRAVERSAL': 0.4430410861968994,
  'DOCUMENT RETRIEVAL': 4.371984958648682,
  'READ FROM CACHE': 0.004430055618286133,
  'CACHE RETRIEVAL': 0.02514362335205078,
  'WRITE TO CACHE': 0.00560307502746582,
  'NUM TOTAL DOCUMENTS': 411},
 {'NODE RETRIEVAL': 2.614206075668335,
  'NODE TRAVERSAL': 0.34651660919189453,
  'DOCUMENT RETRIEVAL': 7.350510358810425,
  'READ FROM CACHE': 0.01123189926147461,
  'CACHE RETRIEVAL': 0.04842782020568848,
  'WRITE TO CACHE': 0.010355710983276367,
  'NUM TOTAL DOCUMENTS': 1893},
 {'NODE RETRIEVAL': 2.0464413166046143,
  'NODE TRAVERSAL': 0.2561614513397217,
  'DOCUMENT RETRIEVAL': 0.523615837097168,
  'READ FROM CACHE': 0.001990079879760742,
  'CACHE RETRIEVAL': 0.0013401508331298828,
  'WRITE TO CACHE': 0.0026273727416992188,
  'NUM TOTAL DOCUMENTS': 26},
 {'NODE RETRIEVAL': 1.9715421199798584,
  'NODE TRAVERSAL': 0.6136579513549805,
  'DOCUMENT RETRIEVAL': 0.9719655513763428,
  'READ FROM CACHE': 0.003938913345336914,
  'CACHE RETRIEVAL': 0.001804351806640625,
  'WRITE TO CACHE': 0.005081653594970703,
  'NUM TOTAL DOCUMENTS': 122},
 {'NODE RETRIEVAL': 2.334766149520874,
  'NODE TRAVERSAL': 0.22342395782470703,
  'DOCUMENT RETRIEVAL': 0.5181238651275635,
  'READ FROM CACHE': 0.0028738975524902344,
  'CACHE RETRIEVAL': 0.0036547183990478516,
  'WRITE TO CACHE': 0.003378152847290039,
  'NUM TOTAL DOCUMENTS': 133},
 {'NODE RETRIEVAL': 1.9937951564788818,
  'NODE TRAVERSAL': 0.3648204803466797,
  'DOCUMENT RETRIEVAL': 2.289064645767212,
  'READ FROM CACHE': 0.0025370121002197266,
  'CACHE RETRIEVAL': 0.001096963882446289,
  'WRITE TO CACHE': 0.006615161895751953,
  'NUM TOTAL DOCUMENTS': 278},
 {'NODE RETRIEVAL': 2.1634609699249268,
  'NODE TRAVERSAL': 0.7527947425842285,
  'DOCUMENT RETRIEVAL': 3.029709815979004,
  'READ FROM CACHE': 0.002227306365966797,
  'CACHE RETRIEVAL': 0.0014448165893554688,
  'WRITE TO CACHE': 0.006253242492675781,
  'NUM TOTAL DOCUMENTS': 396},
 {'NODE RETRIEVAL': 2.2587218284606934,
  'NODE TRAVERSAL': 0.4918050765991211,
  'DOCUMENT RETRIEVAL': 1.0877363681793213,
  'READ FROM CACHE': 0.0025615692138671875,
  'CACHE RETRIEVAL': 0.0019648075103759766,
  'WRITE TO CACHE': 0.004652500152587891,
  'NUM TOTAL DOCUMENTS': 163},
 {'NODE RETRIEVAL': 2.5864858627319336,
  'NODE TRAVERSAL': 0.496706485748291,
  'DOCUMENT RETRIEVAL': 0.5951921939849854,
  'READ FROM CACHE': 0.002951383590698242,
  'CACHE RETRIEVAL': 0.002167224884033203,
  'WRITE TO CACHE': 0.0038924217224121094,
  'NUM TOTAL DOCUMENTS': 77},
 {'NODE RETRIEVAL': 2.28085994720459,
  'NODE TRAVERSAL': 0.6688799858093262,
  'DOCUMENT RETRIEVAL': 0.40610694885253906,
  'READ FROM CACHE': 0.00452876091003418,
  'CACHE RETRIEVAL': 0.005570888519287109,
  'WRITE TO CACHE': 0.003537893295288086,
  'NUM TOTAL DOCUMENTS': 72},
 {'NODE RETRIEVAL': 2.185462236404419,
  'NODE TRAVERSAL': 0.9341111183166504,
  'DOCUMENT RETRIEVAL': 21.374929428100586,
  'READ FROM CACHE': 0.002601146697998047,
  'CACHE RETRIEVAL': 0.0061109066009521484,
  'WRITE TO CACHE': 0.02760624885559082,
  'NUM TOTAL DOCUMENTS': 1280},
 {'NODE RETRIEVAL': 2.865328073501587,
  'NODE TRAVERSAL': 0.2829744815826416,
  'DOCUMENT RETRIEVAL': 0.458909273147583,
  'READ FROM CACHE': 0.002325773239135742,
  'CACHE RETRIEVAL': 0.0014560222625732422,
  'WRITE TO CACHE': 0.0039021968841552734,
  'NUM TOTAL DOCUMENTS': 67},
 {'NODE RETRIEVAL': 2.201586961746216,
  'NODE TRAVERSAL': 0.22478079795837402,
  'DOCUMENT RETRIEVAL': 0.06580591201782227,
  'READ FROM CACHE': 0.00274658203125,
  'CACHE RETRIEVAL': 0.0027654170989990234,
  'WRITE TO CACHE': 0.0008518695831298828,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.4545609951019287,
  'NODE TRAVERSAL': 0.19171929359436035,
  'DOCUMENT RETRIEVAL': 1.1305346488952637,
  'READ FROM CACHE': 0.003016233444213867,
  'CACHE RETRIEVAL': 0.0075910091400146484,
  'WRITE TO CACHE': 0.002307891845703125,
  'NUM TOTAL DOCUMENTS': 311},
 {'NODE RETRIEVAL': 2.4583370685577393,
  'NODE TRAVERSAL': 0.17926383018493652,
  'DOCUMENT RETRIEVAL': 0.1514112949371338,
  'READ FROM CACHE': 0.0028905868530273438,
  'CACHE RETRIEVAL': 0.004523754119873047,
  'WRITE TO CACHE': 0.001984834671020508,
  'NUM TOTAL DOCUMENTS': 31},
 {'NODE RETRIEVAL': 2.030686855316162,
  'NODE TRAVERSAL': 0.2986564636230469,
  'DOCUMENT RETRIEVAL': 0.3974454402923584,
  'READ FROM CACHE': 0.0034105777740478516,
  'CACHE RETRIEVAL': 0.009699106216430664,
  'WRITE TO CACHE': 0.0021278858184814453,
  'NUM TOTAL DOCUMENTS': 107},
 {'NODE RETRIEVAL': 2.297517776489258,
  'NODE TRAVERSAL': 0.4794750213623047,
  'DOCUMENT RETRIEVAL': 3.4852802753448486,
  'READ FROM CACHE': 0.0030972957611083984,
  'CACHE RETRIEVAL': 0.0024831295013427734,
  'WRITE TO CACHE': 0.007388114929199219,
  'NUM TOTAL DOCUMENTS': 389},
 {'NODE RETRIEVAL': 2.2535438537597656,
  'NODE TRAVERSAL': 0.8897440433502197,
  'DOCUMENT RETRIEVAL': 0.08343720436096191,
  'READ FROM CACHE': 0.0037343502044677734,
  'CACHE RETRIEVAL': 0.0026285648345947266,
  'WRITE TO CACHE': 0.0023491382598876953,
  'NUM TOTAL DOCUMENTS': 22},
 {'NODE RETRIEVAL': 2.061750888824463,
  'NODE TRAVERSAL': 0.21417808532714844,
  'DOCUMENT RETRIEVAL': 0.14834213256835938,
  'READ FROM CACHE': 0.0019609928131103516,
  'CACHE RETRIEVAL': 0.0017354488372802734,
  'WRITE TO CACHE': 0.0021126270294189453,
  'NUM TOTAL DOCUMENTS': 46},
 {'NODE RETRIEVAL': 2.0743958950042725,
  'NODE TRAVERSAL': 1.12028169631958,
  'DOCUMENT RETRIEVAL': 16.414749145507812,
  'READ FROM CACHE': 0.019815444946289062,
  'CACHE RETRIEVAL': 0.08541488647460938,
  'WRITE TO CACHE': 0.0169069766998291,
  'NUM TOTAL DOCUMENTS': 2468},
 {'NODE RETRIEVAL': 2.4520492553710938,
  'NODE TRAVERSAL': 0.12543034553527832,
  'DOCUMENT RETRIEVAL': 0.20318078994750977,
  'READ FROM CACHE': 0.0020918846130371094,
  'CACHE RETRIEVAL': 0.002786874771118164,
  'WRITE TO CACHE': 0.001712799072265625,
  'NUM TOTAL DOCUMENTS': 58},
 {'NODE RETRIEVAL': 3.670334815979004,
  'NODE TRAVERSAL': 0.45542383193969727,
  'DOCUMENT RETRIEVAL': 6.406586170196533,
  'READ FROM CACHE': 0.002780914306640625,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.010764598846435547,
  'NUM TOTAL DOCUMENTS': 811},
 {'NODE RETRIEVAL': 2.045135974884033,
  'NODE TRAVERSAL': 0.5509097576141357,
  'DOCUMENT RETRIEVAL': 7.394091844558716,
  'READ FROM CACHE': 0.00323486328125,
  'CACHE RETRIEVAL': 0.0011470317840576172,
  'WRITE TO CACHE': 0.012157440185546875,
  'NUM TOTAL DOCUMENTS': 714},
 {'NODE RETRIEVAL': 2.2055108547210693,
  'NODE TRAVERSAL': 0.09742116928100586,
  'DOCUMENT RETRIEVAL': 0.06664419174194336,
  'READ FROM CACHE': 0.0027086734771728516,
  'CACHE RETRIEVAL': 0.002603769302368164,
  'WRITE TO CACHE': 0.0008661746978759766,
  'NUM TOTAL DOCUMENTS': 18},
 {'NODE RETRIEVAL': 2.2546989917755127,
  'NODE TRAVERSAL': 0.1766047477722168,
  'DOCUMENT RETRIEVAL': 2.762312412261963,
  'READ FROM CACHE': 0.00980377197265625,
  'CACHE RETRIEVAL': 0.05392956733703613,
  'WRITE TO CACHE': 0.003644227981567383,
  'NUM TOTAL DOCUMENTS': 645},
 {'NODE RETRIEVAL': 2.2664549350738525,
  'NODE TRAVERSAL': 0.7307846546173096,
  'DOCUMENT RETRIEVAL': 15.256454467773438,
  'READ FROM CACHE': 0.005767107009887695,
  'CACHE RETRIEVAL': 0.016144275665283203,
  'WRITE TO CACHE': 0.020848751068115234,
  'NUM TOTAL DOCUMENTS': 1915},
 {'NODE RETRIEVAL': 2.215625047683716,
  'NODE TRAVERSAL': 1.1934125423431396,
  'DOCUMENT RETRIEVAL': 14.316442251205444,
  'READ FROM CACHE': 0.0019466876983642578,
  'CACHE RETRIEVAL': 0.00018787384033203125,
  'WRITE TO CACHE': 0.018643856048583984,
  'NUM TOTAL DOCUMENTS': 949},
 {'NODE RETRIEVAL': 2.388684034347534,
  'NODE TRAVERSAL': 0.12693500518798828,
  'DOCUMENT RETRIEVAL': 0.021029949188232422,
  'READ FROM CACHE': 0.006165504455566406,
  'CACHE RETRIEVAL': 0.029995203018188477,
  'WRITE TO CACHE': 0.0012710094451904297,
  'NUM TOTAL DOCUMENTS': 364},
 {'NODE RETRIEVAL': 2.3640592098236084,
  'NODE TRAVERSAL': 0.35607481002807617,
  'DOCUMENT RETRIEVAL': 0.4132869243621826,
  'READ FROM CACHE': 0.003496408462524414,
  'CACHE RETRIEVAL': 0.003335714340209961,
  'WRITE TO CACHE': 0.004903078079223633,
  'NUM TOTAL DOCUMENTS': 90},
 {'NODE RETRIEVAL': 2.4645256996154785,
  'NODE TRAVERSAL': 0.14756512641906738,
  'DOCUMENT RETRIEVAL': 3.4522299766540527,
  'READ FROM CACHE': 0.0056934356689453125,
  'CACHE RETRIEVAL': 0.029209375381469727,
  'WRITE TO CACHE': 0.0053369998931884766,
  'NUM TOTAL DOCUMENTS': 739},
 {'NODE RETRIEVAL': 2.060767889022827,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.004854917526245117,
  'CACHE RETRIEVAL': 0.011926651000976562,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 118},
 {'NODE RETRIEVAL': 1.92539381980896,
  'NODE TRAVERSAL': 0.6234426498413086,
  'DOCUMENT RETRIEVAL': 0.29509925842285156,
  'READ FROM CACHE': 0.003634214401245117,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.00617527961730957,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 9.000476837158203,
  'NODE TRAVERSAL': 0.23636102676391602,
  'DOCUMENT RETRIEVAL': 1.262378454208374,
  'READ FROM CACHE': 0.0013875961303710938,
  'CACHE RETRIEVAL': 0.0009751319885253906,
  'WRITE TO CACHE': 0.0030202865600585938,
  'NUM TOTAL DOCUMENTS': 202},
 {'NODE RETRIEVAL': 3.6914548873901367,
  'NODE TRAVERSAL': 0.3383448123931885,
  'DOCUMENT RETRIEVAL': 1.196293592453003,
  'READ FROM CACHE': 0.002735137939453125,
  'CACHE RETRIEVAL': 0.0008950233459472656,
  'WRITE TO CACHE': 0.004911899566650391,
  'NUM TOTAL DOCUMENTS': 185},
 {'NODE RETRIEVAL': 1.8380742073059082,
  'NODE TRAVERSAL': 0.280010461807251,
  'DOCUMENT RETRIEVAL': 1.0100955963134766,
  'READ FROM CACHE': 0.0024809837341308594,
  'CACHE RETRIEVAL': 0.0034971237182617188,
  'WRITE TO CACHE': 0.004004240036010742,
  'NUM TOTAL DOCUMENTS': 171},
 {'NODE RETRIEVAL': 2.4564249515533447,
  'NODE TRAVERSAL': 0.23551607131958008,
  'DOCUMENT RETRIEVAL': 8.340953588485718,
  'READ FROM CACHE': 0.026869535446166992,
  'CACHE RETRIEVAL': 0.4874868392944336,
  'WRITE TO CACHE': 0.008995294570922852,
  'NUM TOTAL DOCUMENTS': 1933},
 {'NODE RETRIEVAL': 2.831078052520752,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.005862236022949219,
  'CACHE RETRIEVAL': 0.0072171688079833984,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.2485861778259277,
  'NODE TRAVERSAL': 0.6009230613708496,
  'DOCUMENT RETRIEVAL': 0.1661994457244873,
  'READ FROM CACHE': 0.0034270286560058594,
  'CACHE RETRIEVAL': 0.0005440711975097656,
  'WRITE TO CACHE': 0.004033803939819336,
  'NUM TOTAL DOCUMENTS': 34},
 {'NODE RETRIEVAL': 2.0939829349517822,
  'NODE TRAVERSAL': 0.7537064552307129,
  'DOCUMENT RETRIEVAL': 7.158273935317993,
  'READ FROM CACHE': 0.016216754913330078,
  'CACHE RETRIEVAL': 0.09052300453186035,
  'WRITE TO CACHE': 0.011140823364257812,
  'NUM TOTAL DOCUMENTS': 1802},
 {'NODE RETRIEVAL': 2.2497260570526123,
  'NODE TRAVERSAL': 0.6712141036987305,
  'DOCUMENT RETRIEVAL': 4.550626993179321,
  'READ FROM CACHE': 0.0020084381103515625,
  'CACHE RETRIEVAL': 0.0014400482177734375,
  'WRITE TO CACHE': 0.010738372802734375,
  'NUM TOTAL DOCUMENTS': 539},
 {'NODE RETRIEVAL': 3.485440969467163,
  'NODE TRAVERSAL': 0.3429129123687744,
  'DOCUMENT RETRIEVAL': 0.8252344131469727,
  'READ FROM CACHE': 0.002707242965698242,
  'CACHE RETRIEVAL': 0.004196643829345703,
  'WRITE TO CACHE': 0.0031702518463134766,
  'NUM TOTAL DOCUMENTS': 223},
 {'NODE RETRIEVAL': 4.164407968521118,
  'NODE TRAVERSAL': 0.7090373039245605,
  'DOCUMENT RETRIEVAL': 0.2234501838684082,
  'READ FROM CACHE': 0.003754854202270508,
  'CACHE RETRIEVAL': 0.0008749961853027344,
  'WRITE TO CACHE': 0.004979848861694336,
  'NUM TOTAL DOCUMENTS': 38},
 {'NODE RETRIEVAL': 3.3957393169403076,
  'NODE TRAVERSAL': 0.2161695957183838,
  'DOCUMENT RETRIEVAL': 5.2046732902526855,
  'READ FROM CACHE': 0.013751745223999023,
  'CACHE RETRIEVAL': 0.3835897445678711,
  'WRITE TO CACHE': 0.0071218013763427734,
  'NUM TOTAL DOCUMENTS': 1809},
 {'NODE RETRIEVAL': 3.052324056625366,
  'NODE TRAVERSAL': 0.2154221534729004,
  'DOCUMENT RETRIEVAL': 0.10674214363098145,
  'READ FROM CACHE': 0.004418849945068359,
  'CACHE RETRIEVAL': 0.0069239139556884766,
  'WRITE TO CACHE': 0.001964569091796875,
  'NUM TOTAL DOCUMENTS': 32},
 {'NODE RETRIEVAL': 2.6492888927459717,
  'NODE TRAVERSAL': 0.5127849578857422,
  'DOCUMENT RETRIEVAL': 0.47428011894226074,
  'READ FROM CACHE': 0.0055484771728515625,
  'CACHE RETRIEVAL': 0.015196800231933594,
  'WRITE TO CACHE': 0.006183624267578125,
  'NUM TOTAL DOCUMENTS': 312},
 {'NODE RETRIEVAL': 2.2604637145996094,
  'NODE TRAVERSAL': 0.27590322494506836,
  'DOCUMENT RETRIEVAL': 0.8730282783508301,
  'READ FROM CACHE': 0.0032444000244140625,
  'CACHE RETRIEVAL': 0.0007739067077636719,
  'WRITE TO CACHE': 0.004993915557861328,
  'NUM TOTAL DOCUMENTS': 196},
 {'NODE RETRIEVAL': 2.6799051761627197,
  'NODE TRAVERSAL': 0.17868733406066895,
  'DOCUMENT RETRIEVAL': 0.1385047435760498,
  'READ FROM CACHE': 0.003068685531616211,
  'CACHE RETRIEVAL': 0.0028543472290039062,
  'WRITE TO CACHE': 0.0016322135925292969,
  'NUM TOTAL DOCUMENTS': 22},
 {'NODE RETRIEVAL': 2.048610210418701,
  'NODE TRAVERSAL': 0.2122950553894043,
  'DOCUMENT RETRIEVAL': 0.40526747703552246,
  'READ FROM CACHE': 0.0024323463439941406,
  'CACHE RETRIEVAL': 0.0024683475494384766,
  'WRITE TO CACHE': 0.002586841583251953,
  'NUM TOTAL DOCUMENTS': 47},
 {'NODE RETRIEVAL': 2.873322010040283,
  'NODE TRAVERSAL': 0.27327799797058105,
  'DOCUMENT RETRIEVAL': 1.0920257568359375,
  'READ FROM CACHE': 0.004631519317626953,
  'CACHE RETRIEVAL': 0.02209186553955078,
  'WRITE TO CACHE': 0.004291534423828125,
  'NUM TOTAL DOCUMENTS': 374},
 {'NODE RETRIEVAL': 2.4347188472747803,
  'NODE TRAVERSAL': 0.25070905685424805,
  'DOCUMENT RETRIEVAL': 0.4162278175354004,
  'READ FROM CACHE': 0.0026781558990478516,
  'CACHE RETRIEVAL': 0.0038290023803710938,
  'WRITE TO CACHE': 0.002079010009765625,
  'NUM TOTAL DOCUMENTS': 46},
 {'NODE RETRIEVAL': 2.296588897705078,
  'NODE TRAVERSAL': 0.18323612213134766,
  'DOCUMENT RETRIEVAL': 0.7044999599456787,
  'READ FROM CACHE': 0.002351999282836914,
  'CACHE RETRIEVAL': 0.004708290100097656,
  'WRITE TO CACHE': 0.0022001266479492188,
  'NUM TOTAL DOCUMENTS': 156},
 {'NODE RETRIEVAL': 2.044132947921753,
  'NODE TRAVERSAL': 0.18405580520629883,
  'DOCUMENT RETRIEVAL': 0.6236019134521484,
  'READ FROM CACHE': 0.0038666725158691406,
  'CACHE RETRIEVAL': 0.011755943298339844,
  'WRITE TO CACHE': 0.001718759536743164,
  'NUM TOTAL DOCUMENTS': 145},
 {'NODE RETRIEVAL': 3.1533279418945312,
  'NODE TRAVERSAL': 0.6878955364227295,
  'DOCUMENT RETRIEVAL': 0.26109766960144043,
  'READ FROM CACHE': 0.0030755996704101562,
  'CACHE RETRIEVAL': 0.0005037784576416016,
  'WRITE TO CACHE': 0.004731655120849609,
  'NUM TOTAL DOCUMENTS': 38},
 {'NODE RETRIEVAL': 2.555779218673706,
  'NODE TRAVERSAL': 0.26145100593566895,
  'DOCUMENT RETRIEVAL': 1.7420310974121094,
  'READ FROM CACHE': 0.01413273811340332,
  'CACHE RETRIEVAL': 0.09555792808532715,
  'WRITE TO CACHE': 0.005807638168334961,
  'NUM TOTAL DOCUMENTS': 1272},
 {'NODE RETRIEVAL': 2.371443033218384,
  'NODE TRAVERSAL': 0.2210230827331543,
  'DOCUMENT RETRIEVAL': 0.3040614128112793,
  'READ FROM CACHE': 0.002567768096923828,
  'CACHE RETRIEVAL': 0.00442814826965332,
  'WRITE TO CACHE': 0.0024614334106445312,
  'NUM TOTAL DOCUMENTS': 83},
 {'NODE RETRIEVAL': 1.7901017665863037,
  'NODE TRAVERSAL': 0.5216598510742188,
  'DOCUMENT RETRIEVAL': 5.2807722091674805,
  'READ FROM CACHE': 0.003741741180419922,
  'CACHE RETRIEVAL': 0.013984918594360352,
  'WRITE TO CACHE': 0.010536909103393555,
  'NUM TOTAL DOCUMENTS': 1175},
 {'NODE RETRIEVAL': 2.2598016262054443,
  'NODE TRAVERSAL': 0.3909785747528076,
  'DOCUMENT RETRIEVAL': 0.36827731132507324,
  'READ FROM CACHE': 0.002191781997680664,
  'CACHE RETRIEVAL': 0.0004899501800537109,
  'WRITE TO CACHE': 0.0036749839782714844,
  'NUM TOTAL DOCUMENTS': 50},
 {'NODE RETRIEVAL': 2.0473239421844482,
  'NODE TRAVERSAL': 0.186265230178833,
  'DOCUMENT RETRIEVAL': 0.4025237560272217,
  'READ FROM CACHE': 0.002634286880493164,
  'CACHE RETRIEVAL': 0.005686759948730469,
  'WRITE TO CACHE': 0.002025127410888672,
  'NUM TOTAL DOCUMENTS': 276},
 {'NODE RETRIEVAL': 1.8456621170043945,
  'NODE TRAVERSAL': 0.5841376781463623,
  'DOCUMENT RETRIEVAL': 5.666785717010498,
  'READ FROM CACHE': 0.003438711166381836,
  'CACHE RETRIEVAL': 0.0015020370483398438,
  'WRITE TO CACHE': 0.0113677978515625,
  'NUM TOTAL DOCUMENTS': 584},
 {'NODE RETRIEVAL': 2.553063154220581,
  'NODE TRAVERSAL': 0.5693399906158447,
  'DOCUMENT RETRIEVAL': 0.24619793891906738,
  'READ FROM CACHE': 0.002651691436767578,
  'CACHE RETRIEVAL': 0.0002281665802001953,
  'WRITE TO CACHE': 0.004496097564697266,
  'NUM TOTAL DOCUMENTS': 28},
 {'NODE RETRIEVAL': 2.784229040145874,
  'NODE TRAVERSAL': 0.2315535545349121,
  'DOCUMENT RETRIEVAL': 0.43831419944763184,
  'READ FROM CACHE': 0.0033957958221435547,
  'CACHE RETRIEVAL': 0.006627082824707031,
  'WRITE TO CACHE': 0.0039365291595458984,
  'NUM TOTAL DOCUMENTS': 92},
 {'NODE RETRIEVAL': 2.6401541233062744,
  'NODE TRAVERSAL': 0.2460036277770996,
  'DOCUMENT RETRIEVAL': 0.6091248989105225,
  'READ FROM CACHE': 0.004130840301513672,
  'CACHE RETRIEVAL': 0.008595705032348633,
  'WRITE TO CACHE': 0.00432896614074707,
  'NUM TOTAL DOCUMENTS': 289},
 {'NODE RETRIEVAL': 2.636186122894287,
  'NODE TRAVERSAL': 0.3799591064453125,
  'DOCUMENT RETRIEVAL': 0.3361849784851074,
  'READ FROM CACHE': 0.002849102020263672,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005114555358886719,
  'NUM TOTAL DOCUMENTS': 56},
 {'NODE RETRIEVAL': 2.7596452236175537,
  'NODE TRAVERSAL': 0.42087507247924805,
  'DOCUMENT RETRIEVAL': 0.09131908416748047,
  'READ FROM CACHE': 0.00431513786315918,
  'CACHE RETRIEVAL': 0.0009050369262695312,
  'WRITE TO CACHE': 0.00438237190246582,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 2.073042154312134,
  'NODE TRAVERSAL': 0.21005654335021973,
  'DOCUMENT RETRIEVAL': 1.3591718673706055,
  'READ FROM CACHE': 0.0134429931640625,
  'CACHE RETRIEVAL': 0.03738903999328613,
  'WRITE TO CACHE': 0.004805803298950195,
  'NUM TOTAL DOCUMENTS': 1116},
 {'NODE RETRIEVAL': 3.3936448097229004,
  'NODE TRAVERSAL': 0.21085071563720703,
  'DOCUMENT RETRIEVAL': 0.1637439727783203,
  'READ FROM CACHE': 0.0027430057525634766,
  'CACHE RETRIEVAL': 0.0024085044860839844,
  'WRITE TO CACHE': 0.0019750595092773438,
  'NUM TOTAL DOCUMENTS': 37},
 {'NODE RETRIEVAL': 2.3397469520568848,
  'NODE TRAVERSAL': 0.546771764755249,
  'DOCUMENT RETRIEVAL': 2.4360299110412598,
  'READ FROM CACHE': 0.005583524703979492,
  'CACHE RETRIEVAL': 0.03732609748840332,
  'WRITE TO CACHE': 0.006463527679443359,
  'NUM TOTAL DOCUMENTS': 675},
 {'NODE RETRIEVAL': 2.3003089427948,
  'NODE TRAVERSAL': 0.3961060047149658,
  'DOCUMENT RETRIEVAL': 3.2234878540039062,
  'READ FROM CACHE': 0.005410432815551758,
  'CACHE RETRIEVAL': 0.025801897048950195,
  'WRITE TO CACHE': 0.006944417953491211,
  'NUM TOTAL DOCUMENTS': 765},
 {'NODE RETRIEVAL': 2.1389260292053223,
  'NODE TRAVERSAL': 0.10712361335754395,
  'DOCUMENT RETRIEVAL': 0.03491640090942383,
  'READ FROM CACHE': 0.005728244781494141,
  'CACHE RETRIEVAL': 0.010064840316772461,
  'WRITE TO CACHE': 0.0016298294067382812,
  'NUM TOTAL DOCUMENTS': 50},
 {'NODE RETRIEVAL': 1.840022087097168,
  'NODE TRAVERSAL': 0.39983701705932617,
  'DOCUMENT RETRIEVAL': 0.20705795288085938,
  'READ FROM CACHE': 0.0038962364196777344,
  'CACHE RETRIEVAL': 0.0019292831420898438,
  'WRITE TO CACHE': 0.0044634342193603516,
  'NUM TOTAL DOCUMENTS': 38},
 {'NODE RETRIEVAL': 3.129056930541992,
  'NODE TRAVERSAL': 0.6508059501647949,
  'DOCUMENT RETRIEVAL': 2.6763925552368164,
  'READ FROM CACHE': 0.002587556838989258,
  'CACHE RETRIEVAL': 0.0003581047058105469,
  'WRITE TO CACHE': 0.006999015808105469,
  'NUM TOTAL DOCUMENTS': 394},
 {'NODE RETRIEVAL': 2.547031879425049,
  'NODE TRAVERSAL': 0.39328598976135254,
  'DOCUMENT RETRIEVAL': 0.2001333236694336,
  'READ FROM CACHE': 0.0018758773803710938,
  'CACHE RETRIEVAL': 0.0009646415710449219,
  'WRITE TO CACHE': 0.002757549285888672,
  'NUM TOTAL DOCUMENTS': 41},
 {'NODE RETRIEVAL': 2.1653759479522705,
  'NODE TRAVERSAL': 0.1992480754852295,
  'DOCUMENT RETRIEVAL': 0.2646758556365967,
  'READ FROM CACHE': 0.0023021697998046875,
  'CACHE RETRIEVAL': 0.0012657642364501953,
  'WRITE TO CACHE': 0.0020809173583984375,
  'NUM TOTAL DOCUMENTS': 14},
 {'NODE RETRIEVAL': 2.0475831031799316,
  'NODE TRAVERSAL': 0.2748134136199951,
  'DOCUMENT RETRIEVAL': 0.4637424945831299,
  'READ FROM CACHE': 0.003002166748046875,
  'CACHE RETRIEVAL': 0.00477290153503418,
  'WRITE TO CACHE': 0.0039479732513427734,
  'NUM TOTAL DOCUMENTS': 133},
 {'NODE RETRIEVAL': 4.092078924179077,
  'NODE TRAVERSAL': 0.6026632785797119,
  'DOCUMENT RETRIEVAL': 0.43712520599365234,
  'READ FROM CACHE': 0.0037415027618408203,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.0063266754150390625,
  'NUM TOTAL DOCUMENTS': 79},
 {'NODE RETRIEVAL': 2.8647620677948,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.003819704055786133,
  'CACHE RETRIEVAL': 0.014652252197265625,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 206},
 {'NODE RETRIEVAL': 2.458379030227661,
  'NODE TRAVERSAL': 0.18167996406555176,
  'DOCUMENT RETRIEVAL': 6.374772787094116,
  'READ FROM CACHE': 0.009030580520629883,
  'CACHE RETRIEVAL': 0.060648441314697266,
  'WRITE TO CACHE': 0.007367849349975586,
  'NUM TOTAL DOCUMENTS': 1325},
 {'NODE RETRIEVAL': 2.3394179344177246,
  'NODE TRAVERSAL': 0.07507777214050293,
  'DOCUMENT RETRIEVAL': 0.07905817031860352,
  'READ FROM CACHE': 0.0026421546936035156,
  'CACHE RETRIEVAL': 0.010293245315551758,
  'WRITE TO CACHE': 0.0007774829864501953,
  'NUM TOTAL DOCUMENTS': 143},
 {'NODE RETRIEVAL': 2.392371892929077,
  'NODE TRAVERSAL': 0.17464804649353027,
  'DOCUMENT RETRIEVAL': 3.859699010848999,
  'READ FROM CACHE': 0.010520458221435547,
  'CACHE RETRIEVAL': 0.06772994995117188,
  'WRITE TO CACHE': 0.004683256149291992,
  'NUM TOTAL DOCUMENTS': 1623},
 {'NODE RETRIEVAL': 2.7955210208892822,
  'NODE TRAVERSAL': 0.2805368900299072,
  'DOCUMENT RETRIEVAL': 0.15976214408874512,
  'READ FROM CACHE': 0.0038061141967773438,
  'CACHE RETRIEVAL': 0.002028942108154297,
  'WRITE TO CACHE': 0.0038030147552490234,
  'NUM TOTAL DOCUMENTS': 44},
 {'NODE RETRIEVAL': 2.4501731395721436,
  'NODE TRAVERSAL': 0.5758461952209473,
  'DOCUMENT RETRIEVAL': 0.28322410583496094,
  'READ FROM CACHE': 0.003498077392578125,
  'CACHE RETRIEVAL': 0.0014591217041015625,
  'WRITE TO CACHE': 0.005043506622314453,
  'NUM TOTAL DOCUMENTS': 47},
 {'NODE RETRIEVAL': 2.1745619773864746,
  'NODE TRAVERSAL': 0.3817462921142578,
  'DOCUMENT RETRIEVAL': 0.6055974960327148,
  'READ FROM CACHE': 0.003153085708618164,
  'CACHE RETRIEVAL': 0.00032210350036621094,
  'WRITE TO CACHE': 0.005281209945678711,
  'NUM TOTAL DOCUMENTS': 107},
 {'NODE RETRIEVAL': 2.047010898590088,
  'NODE TRAVERSAL': 0.37723851203918457,
  'DOCUMENT RETRIEVAL': 1.659907341003418,
  'READ FROM CACHE': 0.0040891170501708984,
  'CACHE RETRIEVAL': 0.009826898574829102,
  'WRITE TO CACHE': 0.0055561065673828125,
  'NUM TOTAL DOCUMENTS': 479},
 {'NODE RETRIEVAL': 2.3737480640411377,
  'NODE TRAVERSAL': 0.0855247974395752,
  'DOCUMENT RETRIEVAL': 0.5086510181427002,
  'READ FROM CACHE': 0.012552022933959961,
  'CACHE RETRIEVAL': 0.07280683517456055,
  'WRITE TO CACHE': 0.0019600391387939453,
  'NUM TOTAL DOCUMENTS': 1376},
 {'NODE RETRIEVAL': 2.0888030529022217,
  'NODE TRAVERSAL': 0.1757349967956543,
  'DOCUMENT RETRIEVAL': 0.8624241352081299,
  'READ FROM CACHE': 0.0026352405548095703,
  'CACHE RETRIEVAL': 0.002807140350341797,
  'WRITE TO CACHE': 0.0021011829376220703,
  'NUM TOTAL DOCUMENTS': 56},
 {'NODE RETRIEVAL': 2.1047019958496094,
  'NODE TRAVERSAL': 0.2105882167816162,
  'DOCUMENT RETRIEVAL': 0.12121462821960449,
  'READ FROM CACHE': 0.0030112266540527344,
  'CACHE RETRIEVAL': 0.007086515426635742,
  'WRITE TO CACHE': 0.0009675025939941406,
  'NUM TOTAL DOCUMENTS': 42},
 {'NODE RETRIEVAL': 2.128532886505127,
  'NODE TRAVERSAL': 0.6136338710784912,
  'DOCUMENT RETRIEVAL': 0.13414430618286133,
  'READ FROM CACHE': 0.003180980682373047,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.00526881217956543,
  'NUM TOTAL DOCUMENTS': 23},
 {'NODE RETRIEVAL': 2.9859771728515625,
  'NODE TRAVERSAL': 0.5092105865478516,
  'DOCUMENT RETRIEVAL': 0.5384559631347656,
  'READ FROM CACHE': 0.0030558109283447266,
  'CACHE RETRIEVAL': 0.0,
  'WRITE TO CACHE': 0.005626678466796875,
  'NUM TOTAL DOCUMENTS': 75},
 {'NODE RETRIEVAL': 2.6965560913085938,
  'NODE TRAVERSAL': 0.5003387928009033,
  'DOCUMENT RETRIEVAL': 0.5169548988342285,
  'READ FROM CACHE': 0.002151966094970703,
  'CACHE RETRIEVAL': 0.0017011165618896484,
  'WRITE TO CACHE': 0.0027222633361816406,
  'NUM TOTAL DOCUMENTS': 53},
 {'NODE RETRIEVAL': 2.3885269165039062,
  'NODE TRAVERSAL': 0.4511420726776123,
  'DOCUMENT RETRIEVAL': 0.3060617446899414,
  'READ FROM CACHE': 0.004210472106933594,
  'CACHE RETRIEVAL': 0.007796049118041992,
  'WRITE TO CACHE': 0.003937959671020508,
  'NUM TOTAL DOCUMENTS': 146},
 {'NODE RETRIEVAL': 2.47360897064209,
  'NODE TRAVERSAL': 0.46893882751464844,
  'DOCUMENT RETRIEVAL': 0.04044294357299805,
  'READ FROM CACHE': 0.0040323734283447266,
  'CACHE RETRIEVAL': 0.001447439193725586,
  'WRITE TO CACHE': 0.003961801528930664,
  'NUM TOTAL DOCUMENTS': 18},
 {'NODE RETRIEVAL': 2.2523550987243652,
  'NODE TRAVERSAL': 0.14276504516601562,
  'DOCUMENT RETRIEVAL': 0.9552361965179443,
  'READ FROM CACHE': 0.008907318115234375,
  'CACHE RETRIEVAL': 0.06453990936279297,
  'WRITE TO CACHE': 0.002440214157104492,
  'NUM TOTAL DOCUMENTS': 1016},
 {'NODE RETRIEVAL': 2.670720100402832,
  'NODE TRAVERSAL': 0.05989193916320801,
  'DOCUMENT RETRIEVAL': 0.20894098281860352,
  'READ FROM CACHE': 0.002668142318725586,
  'CACHE RETRIEVAL': 0.005875825881958008,
  'WRITE TO CACHE': 0.0009279251098632812,
  'NUM TOTAL DOCUMENTS': 90},
 {'NODE RETRIEVAL': 3.064265012741089,
  'NODE TRAVERSAL': 0.33336734771728516,
  'DOCUMENT RETRIEVAL': 0.8684625625610352,
  'READ FROM CACHE': 0.003683328628540039,
  'CACHE RETRIEVAL': 0.0014798641204833984,
  'WRITE TO CACHE': 0.005270719528198242,
  'NUM TOTAL DOCUMENTS': 125},
 {'NODE RETRIEVAL': 1.9198551177978516,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.003887176513671875,
  'CACHE RETRIEVAL': 0.009972333908081055,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 43},
 {'NODE RETRIEVAL': 2.0641448497772217,
  'NODE TRAVERSAL': 0.0,
  'DOCUMENT RETRIEVAL': 0.0,
  'READ FROM CACHE': 0.02582573890686035,
  'CACHE RETRIEVAL': 0.3639369010925293,
  'WRITE TO CACHE': 0.0,
  'NUM TOTAL DOCUMENTS': 1261},
 {'NODE RETRIEVAL': 2.8587348461151123,
  'NODE TRAVERSAL': 0.4067215919494629,
  'DOCUMENT RETRIEVAL': 0.12394022941589355,
  'READ FROM CACHE': 0.0041675567626953125,
  'CACHE RETRIEVAL': 1.5974044799804688e-05,
  'WRITE TO CACHE': 0.005349874496459961,
  'NUM TOTAL DOCUMENTS': 21},
 {'NODE RETRIEVAL': 2.7209088802337646,
  'NODE TRAVERSAL': 0.4283926486968994,
  'DOCUMENT RETRIEVAL': 3.110250234603882,
  'READ FROM CACHE': 0.003528118133544922,
  'CACHE RETRIEVAL': 0.0021386146545410156,
  'WRITE TO CACHE': 0.007410287857055664,
  'NUM TOTAL DOCUMENTS': 441},
 {'NODE RETRIEVAL': 2.51064395904541,
  'NODE TRAVERSAL': 0.31256628036499023,
  'DOCUMENT RETRIEVAL': 0.4848935604095459,
  'READ FROM CACHE': 0.0034155845642089844,
  'CACHE RETRIEVAL': 0.006494045257568359,
  'WRITE TO CACHE': 0.003583669662475586,
  'NUM TOTAL DOCUMENTS': 195},
 {'NODE RETRIEVAL': 2.08782696723938,
  'NODE TRAVERSAL': 0.45165205001831055,
  'DOCUMENT RETRIEVAL': 0.4372539520263672,
  'READ FROM CACHE': 0.0029380321502685547,
  'CACHE RETRIEVAL': 0.0024077892303466797,
  'WRITE TO CACHE': 0.0038492679595947266,
  'NUM TOTAL DOCUMENTS': 39},
 {'NODE RETRIEVAL': 1.891261100769043,
  'NODE TRAVERSAL': 0.5750949382781982,
  'DOCUMENT RETRIEVAL': 6.801362991333008,
  'READ FROM CACHE': 0.008728981018066406,
  'CACHE RETRIEVAL': 0.03372693061828613,
  'WRITE TO CACHE': 0.012268304824829102,
  'NUM TOTAL DOCUMENTS': 1033},
 {'NODE RETRIEVAL': 2.5672428607940674,
  'NODE TRAVERSAL': 0.23009991645812988,
  'DOCUMENT RETRIEVAL': 0.28643107414245605,
  'READ FROM CACHE': 0.0031087398529052734,
  'CACHE RETRIEVAL': 0.0013020038604736328,
  'WRITE TO CACHE': 0.002882242202758789,
  'NUM TOTAL DOCUMENTS': 42},
 {'NODE RETRIEVAL': 2.032688856124878,
  'NODE TRAVERSAL': 0.22387123107910156,
  'DOCUMENT RETRIEVAL': 0.7086000442504883,
  'READ FROM CACHE': 0.014412403106689453,
  'CACHE RETRIEVAL': 0.10576081275939941,
  'WRITE TO CACHE': 0.0032753944396972656,
  'NUM TOTAL DOCUMENTS': 688},
 {'NODE RETRIEVAL': 2.4564406871795654,
  'NODE TRAVERSAL': 0.4059147834777832,
  'DOCUMENT RETRIEVAL': 3.3955602645874023,
  'READ FROM CACHE': 0.006937503814697266,
  'CACHE RETRIEVAL': 0.03603005409240723,
  'WRITE TO CACHE': 0.0067386627197265625,
  'NUM TOTAL DOCUMENTS': 578},
 {'NODE RETRIEVAL': 2.9349629878997803,
  'NODE TRAVERSAL': 0.21560096740722656,
  'DOCUMENT RETRIEVAL': 0.17688441276550293,
  'READ FROM CACHE': 0.0041959285736083984,
  'CACHE RETRIEVAL': 0.006552696228027344,
  'WRITE TO CACHE': 0.0024957656860351562,
  'NUM TOTAL DOCUMENTS': 65},
 {'NODE RETRIEVAL': 2.0009610652923584,
  'NODE TRAVERSAL': 0.21486687660217285,
  'DOCUMENT RETRIEVAL': 0.0977773666381836,
  'READ FROM CACHE': 0.005186319351196289,
  'CACHE RETRIEVAL': 0.011950969696044922,
  'WRITE TO CACHE': 0.002887248992919922,
  'NUM TOTAL DOCUMENTS': 106}]

# %%
no_cache_latency_keys = ['DOCUMENT RETRIEVAL', 'NODE RETRIEVAL', 'NODE TRAVERSAL']

# %%
cache_latency_keys = ['NODE RETRIEVAL', 'NODE TRAVERSAL', 'DOCUMENT RETRIEVAL', 'READ FROM CACHE', 'CACHE RETRIEVAL', 'WRITE TO CACHE']

# %%
total_latency_no_cache = [sum([node[key] for key in no_cache_latency_keys]) for node in no_cache_profile]

# %%
total_latency_with_cache = [sum([node[key] for key in cache_latency_keys]) for node in cache_profile]

# %%
total_retrieved_no_cache = [node["NUM TOTAL DOCUMENTS"] for node in no_cache_profile]
total_retrieved_cache = [node["NUM TOTAL DOCUMENTS"] for node in cache_profile]

# %%
import matplotlib.pyplot as plt

plt.scatter(total_retrieved_no_cache, total_latency_no_cache, c='r', s=0.9, label="No Cache Attached")
plt.scatter(total_retrieved_cache, total_latency_with_cache, c='b', s=0.9, label="With Cache")
plt.title("Total Retrieval Latency for No-Cache and With-Cache Retrieval")
plt.xlabel("Number of Documents Retrieved Pre-Truncation")
plt.ylabel("Total Retrieval Latency (s)")
plt.legend()
plt.show()

# %%
avg_latency_no_cache = {key: sum([node[key] for node in no_cache_profile]) / 200.0 for key in no_cache_latency_keys}

# %%
avg_latency_no_cache
# Out:
# {'DOCUMENT RETRIEVAL': 6.263299804925919,
#  'NODE RETRIEVAL': 2.57333939909935,
#  'NODE TRAVERSAL': 0.9218844830989837}

# %%
avg_latency_cache = {key: sum([node[key] for node in cache_profile]) / 200.0 for key in cache_latency_keys}

# %%
avg_latency_cache
# Out:
# {'NODE RETRIEVAL': 3.2464785706996917,
#  'NODE TRAVERSAL': 0.4062730419635773,
#  'DOCUMENT RETRIEVAL': 2.264261344671249,
#  'READ FROM CACHE': 0.004732276201248169,
#  'CACHE RETRIEVAL': 0.02187721252441406,
#  'WRITE TO CACHE': 0.005823869705200196}

# %%
avg_latency_no_cache['READ FROM CACHE'] = 0.0
avg_latency_no_cache['CACHE RETRIEVAL'] = 0.0
avg_latency_no_cache['WRITE TO CACHE'] = 0.0

# %%
import pandas as pd

df = pd.DataFrame([['No Cache Attached', avg_latency_no_cache['NODE RETRIEVAL'], avg_latency_no_cache['NODE TRAVERSAL'], avg_latency_no_cache['DOCUMENT RETRIEVAL'], 
                    0.0, 0.0, 0.0], 
                   ['With Cache', avg_latency_cache['NODE RETRIEVAL'], avg_latency_cache['NODE TRAVERSAL'], avg_latency_cache['DOCUMENT RETRIEVAL'], 
                    avg_latency_cache['READ FROM CACHE'], avg_latency_cache['CACHE RETRIEVAL'], avg_latency_cache['WRITE TO CACHE']]],
                  columns=['Cache State', 'NODE RETRIEVAL', 'NODE TRAVERSAL', 'DOCUMENT RETRIEVAL', 'READ FROM CACHE', 'CACHE RETRIEVAL', 'WRITE TO CACHE'])

# %%
df.plot(x='Cache State', kind='bar', stacked=True,
        title='Average Total Retrieval Latency')
plt.ylabel("Total Retrieval Latency (s)")
plt.show()
